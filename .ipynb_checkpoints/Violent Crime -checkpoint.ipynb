# %%
#Dependencies 
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_file = "Resources/2019 County Health Rankings ALL Data -.csv"

# %%
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#   Unnamed: 0    State   County                         Unnamed: 3  \
# 0        NaN      NaN      NaN                    Premature death
# 1       FIPS    State   County  Years of Potential Life Lost Rate
# 2       1001  Alabama  Autauga                               8824
# 3       1003  Alabama  Baldwin                               7225
# 4       1005  Alabama  Barbour                               9586
#
#      Unnamed: 4     Unnamed: 5 Unnamed: 6         Unnamed: 7  \
# 0           NaN            NaN        NaN                NaN
# 1  95% CI - Low  95% CI - High   Quartile  YPLL Rate (Black)
# 2          7935           9713          1              10471
# 3          6794           7655          1              10042
# 4          8200          10972          1              11333
#
#              Unnamed: 8         Unnamed: 9  ...   Unnamed: 152 Unnamed: 153  \
# 0                   NaN                NaN  ...            NaN          NaN
# 1  YPLL Rate (Hispanic)  YPLL Rate (White)  ...  95% CI - High     Quartile
# 2                   NaN               8707  ...             89            3
# 3                  3087               7278  ...             87            2
# 4                   NaN               7310  ...             86            1
#
#             Unnamed: 154              Unnamed: 155           Unnamed: 156  \
# 0                    NaN                       NaN                    NaN
# 1  % Drive Alone (Black)  % Drive Alone (Hispanic)  % Drive Alone (White)
# 2                     83                       NaN                     84
# 3                     85                        68                     84
# 4                     80                       NaN                     86
#
#                    Unnamed: 157                   Unnamed: 158  Unnamed: 159  \
# 0  Long commute - driving alone                            NaN           NaN
# 1     # Workers who Drive Alone  % Long Commute - Drives Alone  95% CI - Low
# 2                         20911                             38            34
# 3                         74415                             41            38
# 4                          7242                             34            29
#
#     Unnamed: 160 Unnamed: 161
# 0            NaN          NaN
# 1  95% CI - High     Quartile
# 2             42            3
# 3             43            3
# 4             39            2
#
# [5 rows x 162 columns]

# %%
new_data_df = data_file_df[["State","County","Violent Crime"]]
new_data_df.head()
# Out:
#      State   County                  Violent Crime
# 0      NaN      NaN                  Violent crime
# 1    State   County  Annual Average Violent Crimes
# 2  Alabama  Autauga                            149
# 3  Alabama  Baldwin                            408
# 4  Alabama  Barbour                            106

# %%
data_df = new_data_df.drop([0,1])
data_df.head()
# Out:
#      State   County Violent Crime
# 2  Alabama  Autauga           149
# 3  Alabama  Baldwin           408
# 4  Alabama  Barbour           106
# 5  Alabama     Bibb            20
# 6  Alabama   Blount           279

# %%
data_df.to_csv("Resources/CrimeData.csv", index=True, header=True)

# %%
forest_file = "Resources/Forest_Data_Counties.csv"

# %%
forest_file_df = pd.read_csv(forest_file)
forest_file_df.head()
# Out:
#    Unnamed: 0  \
# 0           3
# 1           4
# 2           5
# 3           6
# 4           7
#
#   Table 7. Tree canopy and impervious surface cover characteristics by county.  \
# 0                                     Autauga County
# 1                                     Baldwin County
# 2                                     Barbour County
# 3                                        Bibb County
# 4                                      Blount County
#
#    Mapping Zones  Impervious Cover %  Impervious Cover (m2/person)  \
# 0             46            0.008595                    303.464542
# 1             46            0.012084                    356.483994
# 2             46            0.005891                    462.955438
# 3             48            0.003383                    261.489004
# 4             48            0.008458                    276.601207
#
#    Tree Canopy Cover %  Tree Canopy Cover (m2/person)  Total Green Space (ha)  \
# 0             0.567194                   20026.332898             152866.9952
# 1             0.575551                   16979.382545             409233.9968
# 2             0.605966                   47623.458365             226867.9936
# 3             0.715375                   55289.060981             160413.0048
# 4             0.429399                   14043.195986             165458.9952
#
#    Canopy Green Space %  Available Green Space (ha) State Name
# 0              0.572112                  65410.2016         AL
# 1              0.582591                 170818.9952         AL
# 2              0.609557                  88579.0016         AL
# 3              0.717803                  45268.0000         AL
# 4              0.433062                  93804.9024         AL

# %%
# Merge two dataframes using an inner join
merge_table = pd.merge(data_df, forest_file_df, on="customer_id")
merge_table

# %%
final_data_df = data_df.dropna()
final_data_df.head()
# Out:
#      State   County Violent Crime
# 2  Alabama  Autauga           149
# 3  Alabama  Baldwin           408
# 4  Alabama  Barbour           106
# 5  Alabama     Bibb            20
# 6  Alabama   Blount           279

# %%
final_data_df['Violent Crime'] = pd.to_numeric(final_data_df['Violent Crime'])
# Out:
# C:\Users\nidas\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sum_data = final_data_df.groupby('State')["Violent Crime"]

sum_data.sum()
# Out:
# State
# Alabama                  22717
# Alaska                    3430
# Arizona                  26045
# Arkansas                 14842
# California              163089
# Colorado                 17638
# Connecticut               7901
# Delaware                  4714
# District of Columbia      8218
# Florida                  89946
# Georgia                  38645
# Hawaii                    3477
# Idaho                     3562
# Illinois                 51012
# Indiana                  23155
# Iowa                      8633
# Kansas                   10520
# Kentucky                  9957
# Louisiana                25191
# Maine                     1620
# Maryland                 27698
# Massachusetts            25704
# Michigan                 43840
# Minnesota                12739
# Mississippi               4723
# Missouri                 29025
# Montana                   3133
# Nebraska                  5092
# Nevada                   18874
# New Hampshire             2531
# New Jersey               22394
# New Mexico               12761
# New York                 75235
# North Carolina           31361
# North Dakota              1679
# Ohio                     32605
# Oklahoma                 16752
# Oregon                   10230
# Pennsylvania             40288
# Rhode Island              2426
# South Carolina           24465
# South Dakota              2353
# Tennessee                41274
# Texas                   115069
# Utah                      6765
# Vermont                    741
# Virginia                 17516
# Washington               20716
# West Virginia             5653
# Wisconsin                16796
# Wyoming                   1086
# Name: Violent Crime, dtype: int64

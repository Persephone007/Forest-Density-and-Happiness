# %%
#Dependencies 
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# data_file = "Resources/2019 County Health Rankings ALL Data -.csv"

# %%
# data_file_df = pd.read_csv(data_file)
# data_file_df.head()

# %%
# new_data_df = data_file_df[["State","County","Violent Crime"]]
# new_data_df.head()

# %%
# data_df = new_data_df.drop([0,1])
# data_df.head()

# %%
# data_df.to_csv("Resources/CrimeData.csv", index=True, header=True)

# %%
forest_file = "Resources/forest_fips.csv"
most_data_file = "Resources/full_data_csv.csv"
age_file = "Resources/Health_Data_CSV.csv"

# %%
forest_file_df = pd.read_csv(forest_file)
most_data_file_df = pd.read_csv(most_data_file)
age_file_df = pd.read_csv(age_file)
# forest_file_df.head()

# %%
# Merge two dataframes using an inner join
# data_forest_df = pd.merge(data_df, forest_file_df, on="County", how="outer")
data_forest_college_df = pd.merge(forest_file_df, most_data_file_df, on="County", how="outer")
merge_table_df = pd.merge(data_forest_college_df, age_file_df, on="County", how="outer")
merge_table_df
# Out:
#        State_x               County  Tree Canopy Cover (m2/person)  \
# 0           AL              Autauga                   20026.332900
# 1           AL              Baldwin                   16979.382540
# 2           AL              Baldwin                   16979.382540
# 3           AL              Baldwin                   16979.382540
# 4           AL              Baldwin                   16979.382540
# 5           GA              Baldwin                    8269.977629
# 6           GA              Baldwin                    8269.977629
# 7           GA              Baldwin                    8269.977629
# 8           GA              Baldwin                    8269.977629
# 9           AL              Barbour                   47623.458360
# 10          AL              Barbour                   47623.458360
# 11          AL              Barbour                   47623.458360
# 12          AL              Barbour                   47623.458360
# 13          WV              Barbour                   35073.987020
# 14          WV              Barbour                   35073.987020
# 15          WV              Barbour                   35073.987020
# 16          WV              Barbour                   35073.987020
# 17          AL                 Bibb                   55289.060980
# 18          AL                 Bibb                   55289.060980
# 19          AL                 Bibb                   55289.060980
# 20          AL                 Bibb                   55289.060980
# 21          GA                 Bibb                    2058.984892
# 22          GA                 Bibb                    2058.984892
# 23          GA                 Bibb                    2058.984892
# 24          GA                 Bibb                    2058.984892
# 25          AL               Blount                   14043.195990
# 26          AL               Blount                   14043.195990
# 27          AL               Blount                   14043.195990
# 28          AL               Blount                   14043.195990
# 29          TN               Blount                    7455.477769
# ...        ...                  ...                            ...
# 196364     NaN       Lexington City                            NaN
# 196365     NaN       Lynchburg City                            NaN
# 196366     NaN        Manassas City                            NaN
# 196367     NaN   Manassas Park City                            NaN
# 196368     NaN    Martinsville City                            NaN
# 196369     NaN    Newport News City                            NaN
# 196370     NaN         Norfolk City                            NaN
# 196371     NaN          Norton City                            NaN
# 196372     NaN      Petersburg City                            NaN
# 196373     NaN        Poquoson City                            NaN
# 196374     NaN      Portsmouth City                            NaN
# 196375     NaN         Radford City                            NaN
# 196376     NaN        Richmond City                            NaN
# 196377     NaN         Roanoke City                            NaN
# 196378     NaN           Salem City                            NaN
# 196379     NaN        Staunton City                            NaN
# 196380     NaN         Suffolk City                            NaN
# 196381     NaN  Virginia Beach City                            NaN
# 196382     NaN      Waynesboro City                            NaN
# 196383     NaN    Williamsburg City                            NaN
# 196384     NaN      Winchester City                            NaN
# 196385     NaN         Grays Harbor                            NaN
# 196386     NaN         Pend Oreille                            NaN
# 196387     NaN          Walla Walla                            NaN
# 196388     NaN           Eau Claire                            NaN
# 196389     NaN          Fond du Lac                            NaN
# 196390     NaN           Green Lake                            NaN
# 196391     NaN            La Crosse                            NaN
# 196392     NaN            St. Croix                            NaN
# 196393     NaN          Hot Springs                            NaN
#
#         Total Green Space (ha)   FIPS_x  FIPS_y        State_y  \
# 0                  152866.9952   1001.0    1001        Alabama
# 1                  409233.9968   1003.0    1003        Alabama
# 2                  409233.9968   1003.0    1003        Alabama
# 3                  409233.9968   1003.0   13009        Georgia
# 4                  409233.9968   1003.0   13009        Georgia
# 5                   65536.1984  13009.0    1003        Alabama
# 6                   65536.1984  13009.0    1003        Alabama
# 7                   65536.1984  13009.0   13009        Georgia
# 8                   65536.1984  13009.0   13009        Georgia
# 9                  226867.9936   1005.0    1005        Alabama
# 10                 226867.9936   1005.0    1005        Alabama
# 11                 226867.9936   1005.0   54001  West Virginia
# 12                 226867.9936   1005.0   54001  West Virginia
# 13                  87467.8016  54001.0    1005        Alabama
# 14                  87467.8016  54001.0    1005        Alabama
# 15                  87467.8016  54001.0   54001  West Virginia
# 16                  87467.8016  54001.0   54001  West Virginia
# 17                 160413.0048   1007.0    1007        Alabama
# 18                 160413.0048   1007.0    1007        Alabama
# 19                 160413.0048   1007.0   13021        Georgia
# 20                 160413.0048   1007.0   13021        Georgia
# 21                  60123.5008  13021.0    1007        Alabama
# 22                  60123.5008  13021.0    1007        Alabama
# 23                  60123.5008  13021.0   13021        Georgia
# 24                  60123.5008  13021.0   13021        Georgia
# 25                 165458.9952   1009.0    1009        Alabama
# 26                 165458.9952   1009.0    1009        Alabama
# 27                 165458.9952   1009.0   47009      Tennessee
# 28                 165458.9952   1009.0   47009      Tennessee
# 29                 142483.9936  47009.0    1009        Alabama
# ...                        ...      ...     ...            ...
# 196364                     NaN      NaN   51678       Virginia
# 196365                     NaN      NaN   51680       Virginia
# 196366                     NaN      NaN   51683       Virginia
# 196367                     NaN      NaN   51685       Virginia
# 196368                     NaN      NaN   51690       Virginia
# 196369                     NaN      NaN   51700       Virginia
# 196370                     NaN      NaN   51710       Virginia
# 196371                     NaN      NaN   51720       Virginia
# 196372                     NaN      NaN   51730       Virginia
# 196373                     NaN      NaN   51735       Virginia
# 196374                     NaN      NaN   51740       Virginia
# 196375                     NaN      NaN   51750       Virginia
# 196376                     NaN      NaN   51760       Virginia
# 196377                     NaN      NaN   51770       Virginia
# 196378                     NaN      NaN   51775       Virginia
# 196379                     NaN      NaN   51790       Virginia
# 196380                     NaN      NaN   51800       Virginia
# 196381                     NaN      NaN   51810       Virginia
# 196382                     NaN      NaN   51820       Virginia
# 196383                     NaN      NaN   51830       Virginia
# 196384                     NaN      NaN   51840       Virginia
# 196385                     NaN      NaN   53027     Washington
# 196386                     NaN      NaN   53051     Washington
# 196387                     NaN      NaN   53071     Washington
# 196388                     NaN      NaN   55035      Wisconsin
# 196389                     NaN      NaN   55039      Wisconsin
# 196390                     NaN      NaN   55047      Wisconsin
# 196391                     NaN      NaN   55063      Wisconsin
# 196392                     NaN      NaN   55109      Wisconsin
# 196393                     NaN      NaN   56017        Wyoming
#
#         # Some College  Population  % Some College  Income Ratio  \
# 0                 8701       14298              61           4.6
# 1                31821       48116              66           4.5
# 2                31821       48116              66           4.5
# 3                 5245       10014              52           6.2
# 4                 5245       10014              52           6.2
# 5                31821       48116              66           4.5
# 6                31821       48116              66           4.5
# 7                 5245       10014              52           6.2
# 8                 5245       10014              52           6.2
# 9                 2558        6956              37           5.8
# 10                2558        6956              37           5.8
# 11                1596        3600              44           4.2
# 12                1596        3600              44           4.2
# 13                2558        6956              37           5.8
# 14                2558        6956              37           5.8
# 15                1596        3600              44           4.2
# 16                1596        3600              44           4.2
# 17                3007        6212              48           4.3
# 18                3007        6212              48           4.3
# 19               22771       38613              59           6.4
# 20               22771       38613              59           6.4
# 21                3007        6212              48           4.3
# 22                3007        6212              48           4.3
# 23               22771       38613              59           6.4
# 24               22771       38613              59           6.4
# 25                7526       13831              54           4.1
# 26                7526       13831              54           4.1
# 27               17521       29975              58           4.2
# 28               17521       29975              58           4.2
# 29                7526       13831              54           4.1
# ...                ...         ...             ...           ...
# 196364             418         522              80           6.2
# 196365           12641       17326              73           4.7
# 196366            6786       12605              54           3.5
# 196367            3212        5426              59           3.7
# 196368            1734        3028              57           5.8
# 196369           34298       51715              66           4.3
# 196370           50877       74413              68           5.1
# 196371             845        1213              70           5.9
# 196372            4110        8077              51           5.7
# 196373            2068        2577              80           3.9
# 196374           16818       26533              63           4.3
# 196375            2627        3208              82           6.8
# 196376           48282       71213              68           6.3
# 196377           16246       28048              58           4.7
# 196378            3480        5615              62           3.7
# 196379            3965        6164              64           4.4
# 196380           15619       23216              67           4.3
# 196381          100637      132787              76           3.6
# 196382            3178        5583              57           4.2
# 196383            1898        2591              73           4.8
# 196384            4182        6952              60           4.2
# 196385            9146       16611              55           4.4
# 196386            1282        2435              53           4.5
# 196387            9351       14223              66           4.3
# 196388           18553       25099              74           4.4
# 196389           15716       24119              65           3.8
# 196390            1989        3794              52           3.9
# 196391           21918       27882              79           4.0
# 196392           17603       22375              79           3.5
# 196393             677         982              69           4.3
#
#         Violent Crime Rate   FIPS          State  % < 18  % 65 and over
# 0                    272.0   1001        Alabama    23.9           15.1
# 1                    204.0   1003        Alabama    21.8           19.9
# 2                    204.0  13009        Georgia    19.2           15.6
# 3                    689.0   1003        Alabama    21.8           19.9
# 4                    689.0  13009        Georgia    19.2           15.6
# 5                    204.0   1003        Alabama    21.8           19.9
# 6                    204.0  13009        Georgia    19.2           15.6
# 7                    689.0   1003        Alabama    21.8           19.9
# 8                    689.0  13009        Georgia    19.2           15.6
# 9                    414.0   1005        Alabama    20.8           18.8
# 10                   414.0  54001  West Virginia    19.7           19.7
# 11                   451.0   1005        Alabama    20.8           18.8
# 12                   451.0  54001  West Virginia    19.7           19.7
# 13                   414.0   1005        Alabama    20.8           18.8
# 14                   414.0  54001  West Virginia    19.7           19.7
# 15                   451.0   1005        Alabama    20.8           18.8
# 16                   451.0  54001  West Virginia    19.7           19.7
# 17                    89.0   1007        Alabama    20.6           16.0
# 18                    89.0  13021        Georgia    24.7           15.3
# 19                   501.0   1007        Alabama    20.6           16.0
# 20                   501.0  13021        Georgia    24.7           15.3
# 21                    89.0   1007        Alabama    20.6           16.0
# 22                    89.0  13021        Georgia    24.7           15.3
# 23                   501.0   1007        Alabama    20.6           16.0
# 24                   501.0  13021        Georgia    24.7           15.3
# 25                   483.0   1009        Alabama    23.3           17.8
# 26                   483.0  47009      Tennessee    20.4           19.7
# 27                   354.0   1009        Alabama    23.3           17.8
# 28                   354.0  47009      Tennessee    20.4           19.7
# 29                   483.0   1009        Alabama    23.3           17.8
# ...                    ...    ...            ...     ...            ...
# 196364               124.0  51678       Virginia     9.5           16.3
# 196365               423.0  51680       Virginia    19.4           14.4
# 196366               309.0  51683       Virginia    26.7            9.6
# 196367               148.0  51685       Virginia    24.2            7.8
# 196368               282.0  51690       Virginia    24.7           19.2
# 196369               456.0  51700       Virginia    23.2           12.6
# 196370               603.0  51710       Virginia    19.8           10.8
# 196371               365.0  51720       Virginia    20.7           18.6
# 196372               714.0  51730       Virginia    21.9           16.5
# 196373               129.0  51735       Virginia    21.8           19.3
# 196374               707.0  51740       Virginia    23.5           14.6
# 196375               582.0  51750       Virginia    12.7            9.1
# 196376               596.0  51760       Virginia    17.8           12.8
# 196377               382.0  51770       Virginia    22.5           16.1
# 196378               106.0  51775       Virginia    20.1           18.6
# 196379               153.0  51790       Virginia    19.2           21.1
# 196380               276.0  51800       Virginia    24.6           13.9
# 196381               152.0  51810       Virginia    22.2           13.7
# 196382               187.0  51820       Virginia    23.5           18.1
# 196383               182.0  51830       Virginia    11.2           15.3
# 196384               272.0  51840       Virginia    22.8           15.4
# 196385               244.0  53027     Washington    20.5           20.9
# 196386               130.0  53051     Washington    19.2           25.3
# 196387               239.0  53071     Washington    21.1           17.5
# 196388               142.0  55035      Wisconsin    20.4           15.3
# 196389               191.0  55039      Wisconsin    21.6           18.0
# 196390                42.0  55047      Wisconsin    22.4           21.9
# 196391               138.0  55063      Wisconsin    19.9           15.9
# 196392                63.0  55109      Wisconsin    25.2           13.6
# 196393               105.0  56017        Wyoming    21.3           25.5
#
# [196394 rows x 16 columns]

# %%
# final_data_df = merge_table_df.dropna()
# final_data_df.head()

# %%
final_data_df['Violent Crime'] = pd.to_numeric(final_data_df['Violent Crime'])
# Out:
# C:\Users\nidas\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# sum_data = final_data_df.groupby('State_x')["Violent Crime"]

# sum_data.sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e01a0827cd15> in <module>
# ----> 1 sum_data = final_data_df.groupby('State_x')["Violent Crime"]
#       2
#       3 sum_data.sum()
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     600                          observed=observed,
#     601                          in_axis=in_axis)
# --> 602                 if not isinstance(gpr, Grouping) else gpr)
#     603
#     604         groupings.append(ping)
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     320                     t = self.name or str(type(self.grouper))
#     321                     raise ValueError(
# --> 322                         "Grouper for '{}' not 1-dimensional".format(t))
#     323                 self.grouper = self.index.map(self.grouper)
#     324                 if not (hasattr(self.grouper, "__len__") and
#
# ValueError: Grouper for 'State_x' not 1-dimensional

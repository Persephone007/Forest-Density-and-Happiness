# %%
#Dependencies 
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data_file = "Resources/2019 County Health Rankings ALL Data -.csv"

# %%
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#   Unnamed: 0    State   County                         Unnamed: 3  \
# 0        NaN      NaN      NaN                    Premature death
# 1       FIPS    State   County  Years of Potential Life Lost Rate
# 2       1001  Alabama  Autauga                               8824
# 3       1003  Alabama  Baldwin                               7225
# 4       1005  Alabama  Barbour                               9586
#
#      Unnamed: 4     Unnamed: 5 Unnamed: 6         Unnamed: 7  \
# 0           NaN            NaN        NaN                NaN
# 1  95% CI - Low  95% CI - High   Quartile  YPLL Rate (Black)
# 2          7935           9713          1              10471
# 3          6794           7655          1              10042
# 4          8200          10972          1              11333
#
#              Unnamed: 8         Unnamed: 9  ...   Unnamed: 152 Unnamed: 153  \
# 0                   NaN                NaN  ...            NaN          NaN
# 1  YPLL Rate (Hispanic)  YPLL Rate (White)  ...  95% CI - High     Quartile
# 2                   NaN               8707  ...             89            3
# 3                  3087               7278  ...             87            2
# 4                   NaN               7310  ...             86            1
#
#             Unnamed: 154              Unnamed: 155           Unnamed: 156  \
# 0                    NaN                       NaN                    NaN
# 1  % Drive Alone (Black)  % Drive Alone (Hispanic)  % Drive Alone (White)
# 2                     83                       NaN                     84
# 3                     85                        68                     84
# 4                     80                       NaN                     86
#
#                    Unnamed: 157                   Unnamed: 158  Unnamed: 159  \
# 0  Long commute - driving alone                            NaN           NaN
# 1     # Workers who Drive Alone  % Long Commute - Drives Alone  95% CI - Low
# 2                         20911                             38            34
# 3                         74415                             41            38
# 4                          7242                             34            29
#
#     Unnamed: 160 Unnamed: 161
# 0            NaN          NaN
# 1  95% CI - High     Quartile
# 2             42            3
# 3             43            3
# 4             39            2
#
# [5 rows x 162 columns]

# %%
new_data_df = data_file_df[["State","County","Violent Crime"]]
new_data_df.head()
# Out:
#      State   County                  Violent Crime
# 0      NaN      NaN                  Violent crime
# 1    State   County  Annual Average Violent Crimes
# 2  Alabama  Autauga                            149
# 3  Alabama  Baldwin                            408
# 4  Alabama  Barbour                            106

# %%
data_df = new_data_df.drop([0,1])
data_df.head()
# Out:
#      State   County Violent Crime
# 2  Alabama  Autauga           149
# 3  Alabama  Baldwin           408
# 4  Alabama  Barbour           106
# 5  Alabama     Bibb            20
# 6  Alabama   Blount           279

# %%
data_df.to_csv("Resources/CrimeData.csv", index=True, header=True)

# %%
forest_file = "Resources/forest_fips.csv"
some_college_file = "Resources/some_college.csv"
age_file = "Resources/Health_Data_CSV.csv"

# %%
forest_file_df = pd.read_csv(forest_file)
some_college_file_df = pd.read_csv(some_college_file)
age_file_df = pd.read_csv(age_file)
# forest_file_df.head()

# %%
# Merge two dataframes using an inner join
data_forest_df = pd.merge(data_df, forest_file_df, on="County", how="outer")
data_forest_college_df = pd.merge(data_forest_df, some_college_file_df, on="County", how="outer")
merge_table_df = pd.merge(data_forest_college_df, age_file_df, on="County", how="outer")
merge_table_df
# Out:
#                State_x       County Violent Crime State_y  \
# 0              Alabama      Autauga           149      AL
# 1              Alabama      Baldwin           408      AL
# 2              Alabama      Baldwin           408      AL
# 3              Alabama      Baldwin           408      AL
# 4              Alabama      Baldwin           408      AL
# 5              Alabama      Baldwin           408      GA
# 6              Alabama      Baldwin           408      GA
# 7              Alabama      Baldwin           408      GA
# 8              Alabama      Baldwin           408      GA
# 9              Georgia      Baldwin           316      AL
# 10             Georgia      Baldwin           316      AL
# 11             Georgia      Baldwin           316      AL
# 12             Georgia      Baldwin           316      AL
# 13             Georgia      Baldwin           316      GA
# 14             Georgia      Baldwin           316      GA
# 15             Georgia      Baldwin           316      GA
# 16             Georgia      Baldwin           316      GA
# 17             Alabama      Barbour           106      AL
# 18             Alabama      Barbour           106      AL
# 19             Alabama      Barbour           106      AL
# 20             Alabama      Barbour           106      AL
# 21             Alabama      Barbour           106      WV
# 22             Alabama      Barbour           106      WV
# 23             Alabama      Barbour           106      WV
# 24             Alabama      Barbour           106      WV
# 25       West Virginia      Barbour            75      AL
# 26       West Virginia      Barbour            75      AL
# 27       West Virginia      Barbour            75      AL
# 28       West Virginia      Barbour            75      AL
# 29       West Virginia      Barbour            75      WV
# ...                ...          ...           ...     ...
# 3819042      Wisconsin    Marinette            17      WI
# 3819043      Wisconsin    Milwaukee          9770      WI
# 3819044      Wisconsin       Oconto           NaN      WI
# 3819045      Wisconsin    Outagamie           280      WI
# 3819046      Wisconsin      Ozaukee            52      WI
# 3819047      Wisconsin        Pepin             9      WI
# 3819048      Wisconsin        Price             9      WI
# 3819049      Wisconsin       Racine           409      WI
# 3819050      Wisconsin    St. Croix            54     NaN
# 3819051      Wisconsin         Sauk            71      WI
# 3819052      Wisconsin       Sawyer            31      WI
# 3819053      Wisconsin      Shawano            35      WI
# 3819054      Wisconsin    Sheboygan           183      WI
# 3819055      Wisconsin  Trempealeau            18      WI
# 3819056      Wisconsin        Vilas            10      WI
# 3819057      Wisconsin     Washburn            32      WI
# 3819058      Wisconsin     Waukesha           257      WI
# 3819059      Wisconsin      Waupaca            98      WI
# 3819060      Wisconsin     Waushara            25      WI
# 3819061        Wyoming     Converse            43      WY
# 3819062        Wyoming       Goshen            47      WY
# 3819063        Wyoming  Hot Springs             5     NaN
# 3819064        Wyoming      Laramie           200      WY
# 3819065        Wyoming      Natrona           160      WY
# 3819066        Wyoming     Niobrara           NaN      WY
# 3819067        Wyoming     Sublette             7      WY
# 3819068        Wyoming   Sweetwater           135      WY
# 3819069        Wyoming        Uinta            14      WY
# 3819070        Wyoming     Washakie             7      WY
# 3819071        Wyoming       Weston            10      WY
#
#          Tree Canopy Cover (m2/person)  Total Green Space (ha)   FIPS_x  \
# 0                         20026.332900            1.528670e+05   1001.0
# 1                         16979.382540            4.092340e+05   1003.0
# 2                         16979.382540            4.092340e+05   1003.0
# 3                         16979.382540            4.092340e+05   1003.0
# 4                         16979.382540            4.092340e+05   1003.0
# 5                          8269.977629            6.553620e+04  13009.0
# 6                          8269.977629            6.553620e+04  13009.0
# 7                          8269.977629            6.553620e+04  13009.0
# 8                          8269.977629            6.553620e+04  13009.0
# 9                         16979.382540            4.092340e+05   1003.0
# 10                        16979.382540            4.092340e+05   1003.0
# 11                        16979.382540            4.092340e+05   1003.0
# 12                        16979.382540            4.092340e+05   1003.0
# 13                         8269.977629            6.553620e+04  13009.0
# 14                         8269.977629            6.553620e+04  13009.0
# 15                         8269.977629            6.553620e+04  13009.0
# 16                         8269.977629            6.553620e+04  13009.0
# 17                        47623.458360            2.268680e+05   1005.0
# 18                        47623.458360            2.268680e+05   1005.0
# 19                        47623.458360            2.268680e+05   1005.0
# 20                        47623.458360            2.268680e+05   1005.0
# 21                        35073.987020            8.746780e+04  54001.0
# 22                        35073.987020            8.746780e+04  54001.0
# 23                        35073.987020            8.746780e+04  54001.0
# 24                        35073.987020            8.746780e+04  54001.0
# 25                        47623.458360            2.268680e+05   1005.0
# 26                        47623.458360            2.268680e+05   1005.0
# 27                        47623.458360            2.268680e+05   1005.0
# 28                        47623.458360            2.268680e+05   1005.0
# 29                        35073.987020            8.746780e+04  54001.0
# ...                                ...                     ...      ...
# 3819042                   52137.653700            3.609480e+05  55075.0
# 3819043                      78.274003            4.045490e+04  55079.0
# 3819044                   36215.975300            2.566320e+05  55083.0
# 3819045                    1316.547701            1.590400e+05  55087.0
# 3819046                    1033.351556            5.701310e+04  55089.0
# 3819047                   24109.801750            5.968600e+04  55091.0
# 3819048                  127378.963000            3.224420e+05  55099.0
# 3819049                     560.088121            7.924080e+04  55101.0
# 3819050                            NaN                     NaN      NaN
# 3819051                   10722.154970            2.139610e+05  55111.0
# 3819052                  155174.125000            3.231770e+05  55113.0
# 3819053                   23107.835530            2.291820e+05  55115.0
# 3819054                    1810.734513            1.287810e+05  55117.0
# 3819055                   20057.571570            1.883900e+05  55121.0
# 3819056                   74419.722150            2.226340e+05  55125.0
# 3819057                   89413.196310            2.082990e+05  55129.0
# 3819058                     640.662810            1.316820e+05  55133.0
# 3819059                   12819.083330            1.924650e+05  55135.0
# 3819060                   19718.191590            1.605760e+05  55137.0
# 3819061                   29747.595090            1.101700e+06  56009.0
# 3819062                    1856.643803            5.755770e+05  56015.0
# 3819063                            NaN                     NaN      NaN
# 3819064                     301.824598            6.915840e+05  56021.0
# 3819065                    3504.351344            1.381960e+06  56025.0
# 3819066                   19784.545080            6.790340e+05  56027.0
# 3819067                  350733.102700            1.265200e+06  56035.0
# 3819068                    3241.937628            2.695170e+06  56037.0
# 3819069                   15703.778750            5.362780e+05  56041.0
# 3819070                   26023.041620            5.787980e+05  56043.0
# 3819071                   39349.037930            6.199590e+05  56045.0
#
#          FIPS_y        State_x  Some College  Population  % Some College  \
# 0          1001        Alabama          8701       14298              61
# 1          1003        Alabama         31821       48116              66
# 2          1003        Alabama         31821       48116              66
# 3         13009        Georgia          5245       10014              52
# 4         13009        Georgia          5245       10014              52
# 5          1003        Alabama         31821       48116              66
# 6          1003        Alabama         31821       48116              66
# 7         13009        Georgia          5245       10014              52
# 8         13009        Georgia          5245       10014              52
# 9          1003        Alabama         31821       48116              66
# 10         1003        Alabama         31821       48116              66
# 11        13009        Georgia          5245       10014              52
# 12        13009        Georgia          5245       10014              52
# 13         1003        Alabama         31821       48116              66
# 14         1003        Alabama         31821       48116              66
# 15        13009        Georgia          5245       10014              52
# 16        13009        Georgia          5245       10014              52
# 17         1005        Alabama          2558        6956              37
# 18         1005        Alabama          2558        6956              37
# 19        54001  West Virginia          1596        3600              44
# 20        54001  West Virginia          1596        3600              44
# 21         1005        Alabama          2558        6956              37
# 22         1005        Alabama          2558        6956              37
# 23        54001  West Virginia          1596        3600              44
# 24        54001  West Virginia          1596        3600              44
# 25         1005        Alabama          2558        6956              37
# 26         1005        Alabama          2558        6956              37
# 27        54001  West Virginia          1596        3600              44
# 28        54001  West Virginia          1596        3600              44
# 29         1005        Alabama          2558        6956              37
# ...         ...            ...           ...         ...             ...
# 3819042   55075      Wisconsin          5227        8254              63
# 3819043   55079      Wisconsin        180732      276262              65
# 3819044   55083      Wisconsin          4633        7934              58
# 3819045   55087      Wisconsin         34093       47580              72
# 3819046   55089      Wisconsin         14913       18137              82
# 3819047   55091      Wisconsin           950        1476              64
# 3819048   55099      Wisconsin          1551        2459              63
# 3819049   55101      Wisconsin         29416       46726              63
# 3819050   55109      Wisconsin         17603       22375              79
# 3819051   55111      Wisconsin          9808       15425              64
# 3819052   55113      Wisconsin          1882        3021              62
# 3819053   55115      Wisconsin          5347        8789              61
# 3819054   55117      Wisconsin         17265       27106              64
# 3819055   55121      Wisconsin          4082        6825              60
# 3819056   55125      Wisconsin          2404        3535              68
# 3819057   55129      Wisconsin          1807        2896              62
# 3819058   55133      Wisconsin         72399       89210              81
# 3819059   55135      Wisconsin          6357       11303              56
# 3819060   55137      Wisconsin          2341        4862              48
# 3819061   56009        Wyoming          2064        3328              62
# 3819062   56015        Wyoming          1942        2997              65
# 3819063   56017        Wyoming           677         982              69
# 3819064   56021        Wyoming         18404       25924              71
# 3819065   56025        Wyoming         14830       22733              65
# 3819066   56027        Wyoming           421         626              67
# 3819067   56035        Wyoming          1646        2788              59
# 3819068   56037        Wyoming          7626       12861              59
# 3819069   56041        Wyoming          2955        5287              56
# 3819070   56043        Wyoming          1092        1816              60
# 3819071   56045        Wyoming          1104        1704              65
#
#           FIPS        State_y  % < 18  % 65 and over
# 0         1001        Alabama    23.9           15.1
# 1         1003        Alabama    21.8           19.9
# 2        13009        Georgia    19.2           15.6
# 3         1003        Alabama    21.8           19.9
# 4        13009        Georgia    19.2           15.6
# 5         1003        Alabama    21.8           19.9
# 6        13009        Georgia    19.2           15.6
# 7         1003        Alabama    21.8           19.9
# 8        13009        Georgia    19.2           15.6
# 9         1003        Alabama    21.8           19.9
# 10       13009        Georgia    19.2           15.6
# 11        1003        Alabama    21.8           19.9
# 12       13009        Georgia    19.2           15.6
# 13        1003        Alabama    21.8           19.9
# 14       13009        Georgia    19.2           15.6
# 15        1003        Alabama    21.8           19.9
# 16       13009        Georgia    19.2           15.6
# 17        1005        Alabama    20.8           18.8
# 18       54001  West Virginia    19.7           19.7
# 19        1005        Alabama    20.8           18.8
# 20       54001  West Virginia    19.7           19.7
# 21        1005        Alabama    20.8           18.8
# 22       54001  West Virginia    19.7           19.7
# 23        1005        Alabama    20.8           18.8
# 24       54001  West Virginia    19.7           19.7
# 25        1005        Alabama    20.8           18.8
# 26       54001  West Virginia    19.7           19.7
# 27        1005        Alabama    20.8           18.8
# 28       54001  West Virginia    19.7           19.7
# 29        1005        Alabama    20.8           18.8
# ...        ...            ...     ...            ...
# 3819042  55075      Wisconsin    19.2           23.4
# 3819043  55079      Wisconsin    24.0           13.2
# 3819044  55083      Wisconsin    20.4           20.0
# 3819045  55087      Wisconsin    23.7           14.3
# 3819046  55089      Wisconsin    21.4           19.2
# 3819047  55091      Wisconsin    21.0           21.6
# 3819048  55099      Wisconsin    18.1           25.1
# 3819049  55101      Wisconsin    23.3           16.0
# 3819050  55109      Wisconsin    25.2           13.6
# 3819051  55111      Wisconsin    22.8           18.0
# 3819052  55113      Wisconsin    19.8           25.3
# 3819053  55115      Wisconsin    21.5           20.8
# 3819054  55117      Wisconsin    22.4           17.5
# 3819055  55121      Wisconsin    24.7           17.8
# 3819056  55125      Wisconsin    17.0           30.4
# 3819057  55129      Wisconsin    19.0           25.7
# 3819058  55133      Wisconsin    21.7           18.1
# 3819059  55135      Wisconsin    20.4           20.5
# 3819060  55137      Wisconsin    18.5           23.9
# 3819061  56009        Wyoming    25.1           16.0
# 3819062  56015        Wyoming    20.1           21.6
# 3819063  56017        Wyoming    21.3           25.5
# 3819064  56021        Wyoming    23.4           15.6
# 3819065  56025        Wyoming    24.2           14.7
# 3819066  56027        Wyoming    17.2           21.9
# 3819067  56035        Wyoming    22.9           18.3
# 3819068  56037        Wyoming    26.5           11.4
# 3819069  56041        Wyoming    29.2           13.2
# 3819070  56043        Wyoming    23.8           20.8
# 3819071  56045        Wyoming    20.9           19.4
#
# [3819072 rows x 16 columns]

# %%
# final_data_df = merge_table_df.dropna()
# final_data_df.head()

# %%
final_data_df['Violent Crime'] = pd.to_numeric(final_data_df['Violent Crime'])
# Out:
# C:\Users\nidas\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# sum_data = final_data_df.groupby('State_x')["Violent Crime"]

# sum_data.sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e01a0827cd15> in <module>
# ----> 1 sum_data = final_data_df.groupby('State_x')["Violent Crime"]
#       2
#       3 sum_data.sum()
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     358                                                     sort=sort,
#     359                                                     observed=observed,
# --> 360                                                     mutated=self.mutated)
#     361
#     362         self.obj = obj
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     600                          observed=observed,
#     601                          in_axis=in_axis)
# --> 602                 if not isinstance(gpr, Grouping) else gpr)
#     603
#     604         groupings.append(ping)
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\grouper.py in __init__(self, index, grouper, obj, name, level, sort, observed, in_axis)
#     320                     t = self.name or str(type(self.grouper))
#     321                     raise ValueError(
# --> 322                         "Grouper for '{}' not 1-dimensional".format(t))
#     323                 self.grouper = self.index.map(self.grouper)
#     324                 if not (hasattr(self.grouper, "__len__") and
#
# ValueError: Grouper for 'State_x' not 1-dimensional

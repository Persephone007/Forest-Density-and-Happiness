# %%
import matplotlib.pyplot as plt
import requests
import json

# %%
api_key = "k3RAzKN1Ag14xTPlculT39RZb38LGgsG8n27ZycG"
base_url = "https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?api_key=7C2g6cn47MJDpsp2twWpwR9Y4fTP0j9ELl196HrZ&location=Denver+CO"

# %%
response = requests.get(base_url)
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "fuel_stations": [
#         {
#             "access_code": "public",
#             "access_days_time": "MO: 12:00am-12:00am; TU: 12:00am-12:00am; WE: 12:00am-12:00am; TH: 12:00am-12:00am; FR: 12:00am-12:00am; SA: 12:00am-12:00am; SU: 12:00am-12:00am",
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Denver",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": null,
#             "cng_psi": null,
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": null,
#             "country": "US",
#             "date_last_confirmed": "2019-09-29",
#             "distance": 0.16602,
#             "distance_km": 0.26718,
#             "e85_blender_pump": null,
# ...

# %%
# geocoordinates
lat = "39.7365765"
lon = "-104.9868044"
distance = "100mi"
datetime_ini = "2017-01-01T00:00:00Z"
datetime_end = "2017-12-31T00:00:00Z"

# set up a parameters dictionary
params = {
    "latitude": lat,
    "longitude": lon,
    "distance": distance,
    "Initial Datetime": datetime_ini,
    "End Datetime": datetime_end
}

# url
url = "https://private-anon-32f9b1db35-crimeometer.apiary-mock.com/v1/incidents/stats?lat={lat}&lon={lon}&distance={distance}&datetime_ini={datetime_ini}&datetime_end={datetime_end}"

# run a request using our params dictionary
response = requests.get(url, params=params)

# %%
base_url = "https://private-anon-32f9b1db35-crimeometer.apiary-mock.com/v1/incidents/stats?lat={lat}&lon={lon}&distance={distance}&datetime_ini={datetime_ini}&datetime_end={datetime_end}"

# %%
# convert response to json
places_data = response.json()

# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "report_types": [
#             {
#                 "count": 634,
#                 "type": "Other"
#             },
#             {
#                 "count": 585,
#                 "type": "Theft"
#             },
#             {
#                 "count": 541,
#                 "type": "Assault"
#             }
#         ],
#         "total_incidents": 1760
#     }
# ]

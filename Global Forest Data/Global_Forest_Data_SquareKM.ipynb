# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Global_Forest_SQKM.csv', encoding = 'iso-8859-1')


columns = df.columns

columns

df.head()

dfcopy = df.copy()

dfcopy



# del dfcopy.iloc[0, :]
# del dfcopy.iloc[1, :]
# del dfcopy.iloc[2, :]


# del row2

# dfcopy.drop('Unnamed: 3', axis = 1)
dfcopy.drop([0, 1, 2])
del dfcopy['Unnamed: 3']

dfcopy = dfcopy.drop([0, 1, 2])

dfcopy

columnnames = []

for i in range(62):
    columnnames.append(dfcopy.iloc[0,i])
    
columnnames

dfcopy = dfcopy.rename(columns = {'Data Source': 'Country Name', 'World Development Indicators': 'Country Code'})

for i in range(2,62):
    try:
        dfcopy = dfcopy.rename(columns = {'Unnamed: ' + str(i): dfcopy.iloc[0,i-1]})
    except IndexError:
        break
#     print(f"Unnamed: {str(i)}")

# for i in range(2,62):
#     print(i)

dfcopy
# Debug Statements:
# ~~~~~~~~~~~~~~~~~~
 
# dfcopy.describe()
# dfcopy.shape
# Out:
#                                           Country Name  Country Code  \
# 3                                         Country Name  Country Code
# 4                                                Aruba           ABW
# 5                                          Afghanistan           AFG
# 6                                               Angola           AGO
# 7                                              Albania           ALB
# 8                                              Andorra           AND
# 9                                           Arab World           ARB
# 10                                United Arab Emirates           ARE
# 11                                           Argentina           ARG
# 12                                             Armenia           ARM
# 13                                      American Samoa           ASM
# 14                                 Antigua and Barbuda           ATG
# 15                                           Australia           AUS
# ...

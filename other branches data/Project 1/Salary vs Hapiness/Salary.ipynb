# %%
import requests
import json
from pprint import pprint
url = "https://api.census.gov/data/2018.json"
api_key ="0a5d81de193c0bf5fb15b8554de139f55617fb06"
response = requests.get(url)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "@context": "https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld",
#     "@id": "https://api.census.gov/data/2018/intltrade/imp_exp.json",
#     "@type": "dcat:Catalog",
#     "conformsTo": "https://project-open-data.cio.gov/v1.1/schema",
#     "dataset": [
#         {
#             "@type": "dcat:Dataset",
#             "accessLevel": "public",
#             "bureauCode": [
#                 "006:07"
#             ],
#             "c_dataset": [
#                 "intltrade",
#                 "imp_exp"
#             ],
#             "c_documentationLink": "http://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/intltrade/imp_exp/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/intltrade/imp_exp/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/intltrade/imp_exp/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_isCube": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/intltrade/imp_exp/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/intltrade/imp_exp/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Foreign Trade Staff",
#                 "hasEmail": "EID.International.Trade.Data@census.gov"
#             },
#             "description": "This international trade file provides the annual dollar value of U.S. exports and imports of goods for all U.S. trade partners.  It also provides the annual dollar value of U.S. exports and imports of manufactured goods for all U.S. trade partners.  You can find this data and more by going to usatrade.census.gov.  If you have any questions regarding U.S. international trade data, please call us at 1(800)549-0595 option #4 or email us at eid.international.trade.data@census.gov.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/intltrade/imp_exp",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "http://api.census.gov/data/id/ftd18ImpExpHist",
#             "keyword": [],
#             "license": "http://creativecommons.org/publicdomain/zero/1.0/Public Domain",
#             "modified": "2019-03-13",
#             "programCode": [
#                 "000:000"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "http://www.census.gov/developers/"
#             ],
#             "spatial": "United States",
#             "temporal": "2018/2018",
#             "title": "2018 International Trade: Historical Imports and Exports"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "accessLevel": "public",
#             "bureauCode": [
#                 "006:07"
#             ],
#             "c_dataset": [
#                 "pdb",
#                 "blockgroup"
#             ],
#             "c_documentationLink": "http://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pdb/blockgroup/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pdb/blockgroup/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pdb/blockgroup/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_tagsLink": "https://api.census.gov/data/2018/pdb/blockgroup/tags.json",
#             "c_valuesLink": "https://api.census.gov/data/2018/pdb/blockgroup/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pdb/blockgroup/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Planning Database questions",
#                 "hasEmail": "census.pdb.questions@census.gov"
#             },
#             "description": "The PDB is a database of U.S. housing, demographic, socioeconomic and operational statistics based on select 2010 Decennial Census and select  5-year American Community Survey (ACS) estimates. Data are provided at the census block group level of geography. These data can be used for many purposes, including survey field operations planning.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pdb/blockgroup",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "http://api.census.gov/data/id/PDBBLOCKGROUP2018",
#             "keyword": [],
#             "license": "http://creativecommons.org/publicdomain/zero/1.0/Public Domain",
#             "modified": "2018-07-19",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "http://www.census.gov/developers/"
#             ],
#             "spatial": "United States",
#             "temporal": "2018/2018",
#             "title": "2018 Census Planning Database: Block Group"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "accessLevel": "public",
#             "bureauCode": [
#                 "006:07"
#             ],
#             "c_dataset": [
#                 "pdb",
#                 "tract"
#             ],
#             "c_documentationLink": "http://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pdb/tract/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pdb/tract/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pdb/tract/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_tagsLink": "https://api.census.gov/data/2018/pdb/tract/tags.json",
#             "c_valuesLink": "https://api.census.gov/data/2018/pdb/tract/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pdb/tract/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Planning Database questions",
#                 "hasEmail": "census.pdb.questions@census.gov"
#             },
#             "description": "The PDB is a database of U.S. housing, demographic, socioeconomic and operational statistics based on select 2010 Decennial Census and select  5-year American Community Survey (ACS) estimates. Data are provided at the census tract level of geography. These data can be used for many purposes, including survey field operations planning.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pdb/tract",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "http://api.census.gov/data/id/PDBTRACT2018",
#             "keyword": [],
#             "license": "http://creativecommons.org/publicdomain/zero/1.0/Public Domain",
#             "modified": "2018-07-19",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "http://www.census.gov/developers/"
#             ],
#             "spatial": "United States",
#             "temporal": "2018/2018",
#             "title": "2018 Census Planning Database: Tract Level"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "pep",
#                 "natmonthly"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pep/natmonthly/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pep/natmonthly/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pep/natmonthly/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/pep/natmonthly/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pep/natmonthly/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Population Estimates Branch",
#                 "hasEmail": "pop.population.estimates@census.gov"
#             },
#             "description": "Monthly Population Estimates by Universe, Age, Sex, Race, and Hispanic Origin for the United States: April 1, 2010 to December 1, 2018 // Source: U.S. Census Bureau, Population Division // The contents of this file are released on a rolling basis from December through June. // Note: 'In combination' means in combination with one or more other races. The sum of the five race-in-combination groups adds to more than the total population because individuals may report more than one race. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see https://www2.census.gov/programs-surveys/popest/technical-documentation/methodology/modified-race-summary-file-method/mrsf2010.pdf. // The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. // Persons on active duty in the Armed Forces were not enumerated in the 2010 Census. Therefore, variables for the 2010 Census civilian, civilian noninstitutionalized, and resident population plus Armed Forces overseas populations cannot be derived and are not available on these files. // For detailed information about the methods used to create the population estimates, see https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2017) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: https://www.census.gov/programs-surveys/popest.html.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pep/natmonthly",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/PEPNATMONTHLY2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/unidentified",
#             "modified": "2018-12-10 00:00:00.0",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "Vintage 2018 Population Estimates: National Monthly Population Estimates"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "pep",
#                 "charage"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pep/charage/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pep/charage/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pep/charage/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/pep/charage/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pep/charage/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Population Estimates Branch",
#                 "hasEmail": "mailto:pop.population.estimates@census.gov"
#             },
#             "description": "Annual Resident Population Estimates by Single Year of Age, Sex, Race, and Hispanic Origin // Source: U.S. Census Bureau, Population Division // Note: 'In combination' means in combination with one or more other races. The sum of the five race-in-combination groups adds to more than the total population because individuals may report more than one race. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data.  // The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. // The vintage year refers to the final year of the time series. Each vintage of estimates includes all years since the most recent decennial census.  The latest vintage estimates supersede all previous vintage estimates. More information about the Population Estimates Program, methodologies, and other products are available at https://www.census.gov/programs-surveys/popest.html.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pep/charage",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/PEPCHARAGE2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2019-03-13 00:00:00.0",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "Vintage 2018 Population Estimates: Characteristics by Single Year of Age"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "pep",
#                 "charagegroups"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pep/charagegroups/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pep/charagegroups/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pep/charagegroups/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/pep/charagegroups/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pep/charagegroups/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Population Estimates Branch",
#                 "hasEmail": "mailto:pop.population.estimates@census.gov"
#             },
#             "description": "Annual Resident Population Estimates by Age Group, Sex, Race, and Hispanic Origin: April 1, 2010 to July 1, 2018 // Source: U.S. Census Bureau, Population Division // The contents of this file are released on a rolling basis from December through June. // Note: 'In combination' means in combination with one or more other races. The sum of the five race-in-combination groups adds to more than the total population because individuals may report more than one race. Hispanic origin is considered an ethnicity, not a race. Hispanics may be of any race. Responses of 'Some Other Race' from the 2010 Census are modified. This results in differences between the population for specific race categories shown for the 2010 Census population in this file versus those in the original 2010 Census data. For more information, see https://www2.census.gov/programs-surveys/popest/technical-documentation/methodology/modified-race-summary-file-method/mrsf2010.pdf. // The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. // For detailed information about the methods used to create the population estimates, see https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2017) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: https://www.census.gov/programs-surveys/popest.html.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pep/charagegroups",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/PEPCHARAGEGROUPS2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2018-12-10 00:00:00.0",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "Vintage 2018 Population Estimates: Demographic Characteristics Estimates by Age Groups"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "pep",
#                 "population"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pep/population/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pep/population/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pep/population/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/pep/population/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pep/population/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Population Estimates Branch",
#                 "hasEmail": "mailto:pop.population.estimates@census.gov"
#             },
#             "description": "Annual Population Estimates for the United States; States; Metropolitan Statistical Areas, Micropolitan Statistical Areas, and Related Statistical Areas; Counties; and Subcounty Places; and for Puerto Rico and Its Municipios: April 1, 2010 to July 1, 2018 // Source: U.S. Census Bureau, Population Division // The contents of this file are released on a rolling basis from December through May. // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program and geographic program revisions. // The Office of Management and Budget's statistical area delineations for metropolitan, micropolitan, and combined statistical areas, as well as metropolitan divisions, are those issued by that agency in July 2015. // The 2010 Census did not ascertain the military status of the household population. Therefore, variables for the 2010 Census civilian, civilian noninstitutionalized, and resident population plus Armed Forces overseas populations cannot be derived and are not available on this file. // For detailed information about the methods used to create the population estimates, see https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., Vintage 2017) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: https://www.census.gov/programs-surveys/popest.html.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pep/population",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/PEPPOP2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2018-12-10 00:00:00.0",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "Vintage 2018 Population Estimates: Population Estimates"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "pep",
#                 "components"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pep/components/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pep/components/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pep/components/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/pep/components/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pep/components/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Population Estimates Branch",
#                 "hasEmail": "mailto:pop.population.estimates@census.gov"
#             },
#             "description": "Annual Resident Population Estimates, Estimated Components of Resident Population Change, and Rates of the Components of Resident Population Change: April 1, 2010 to July 1, 2018 // Source: U.S. Census Bureau, Population Division // The contents of this file are released on a rolling basis from December through March. // Note: Total population change includes a residual. This residual represents the change in population that cannot be attributed to any specific demographic component. See the Population Estimates Glossary at https://www.census.gov/programs-surveys/popest/about/glossary.html. // Net international migration in the United States includes the international migration of both native and foreign-born populations. Specifically, it includes: (a) the net international migration of the foreign born, (b) the net migration between the United States and Puerto Rico, (c) the net migration of natives to and from the United States, and (d) the net movement of the Armed Forces population between the United States and overseas. // The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 population due to the Count Question Resolution program.// The Office of Management and Budget's statistical area delineations for metropolitan, micropolitan, and combined statistical areas, as well as metropolitan divisions, are those issued by that agency in July 2015. // For detailed information about the methods used to create the population estimates, see https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. // Each year, the Census Bureau's Population Estimates Program (PEP) utilizes current data on births, deaths, and migration to calculate population change since the most recent decennial census, and produces a time series of estimates of population. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., Vintage 2018) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population Estimates Program provides additional information including historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: https://www.census.gov/programs-surveys/popest.html.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pep/components",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/PEPCOMPONENTS2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2018-12-10 00:00:00.0",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "Vintage 2018 Population Estimates: Components of Change Estimates"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "pep",
#                 "housing"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/pep/housing/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/pep/housing/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/pep/housing/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/pep/housing/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/pep/housing/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "Population Estimates Branch",
#                 "hasEmail": "mailto:pop.population.estimates@census.gov"
#             },
#             "description": "Annual Housing Unit Estimates for the United States, States, and Counties // Source: U.S. Census Bureau, Population Division // Note: The estimates are based on the 2010 Census and reflect changes to the April 1, 2010 housing units due to the Count Question Resolution program and geographic program revisions. For the housing unit estimates methodology statement, see https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html.// Each year, the Census Bureau's Population and Housing Unit Estimates Program utilizes current data on new residential construction, placements of manufactured housing, and housing unit loss to calculate change in the housing stock since the most recent decennial census, and produces a time series of housing unit estimates.. The annual time series of estimates begins with the most recent decennial census data and extends to the vintage year. The vintage year (e.g., V2018) refers to the final year of the time series. The reference date for all estimates is July 1, unless otherwise specified. With each new issue of estimates, the Census Bureau revises estimates for years back to the last census. As each vintage of estimates includes all years since the most recent decennial census, the latest vintage of data available supersedes all previously produced estimates for those dates. The Population and Housing Unit Estimates Program provides additional information including population estimates, historical and intercensal estimates, evaluation estimates, demographic analysis, and research papers on its website: https://www.census.gov/programs-surveys/popest.html.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/pep/housing",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/PEPHOUSING2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2019-05-23 16:55:50.0",
#             "programCode": [
#                 "006:008"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "Vintage 2018 Population Estimates: Housing Unit Estimates for US, States, and Counties"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "acs",
#                 "acs1"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/acs/acs1/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/acs/acs1/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/acs/acs1/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_isCube": true,
#             "c_tagsLink": "https://api.census.gov/data/2018/acs/acs1/tags.json",
#             "c_valuesLink": "https://api.census.gov/data/2018/acs/acs1/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/acs/acs1/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "American Community Survey Office",
#                 "hasEmail": "mailto:acso.users.support@census.gov"
#             },
#             "description": "The American Community Survey (ACS) is an ongoing survey that provides data every year -- giving communities the current information they need to plan investments and services. The ACS covers a broad range of topics about social, economic, demographic, and housing characteristics of the U.S. population. Much of the ACS data provided on the Census Bureau's Web site are available separately by age group, race, Hispanic origin, and sex.  Summary files, Subject tables, Data profiles, and Comparison profiles are available for the nation, all 50 states, the District of Columbia, Puerto Rico, every congressional district, every metropolitan area, and all counties and places with populations of 65,000 or more.  Detail Tables contain the most detailed cross-tabulations published for areas 65k and more. The data are population counts. There are over 31,000 variables in this dataset.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/acs/acs1",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/ACSDT1Y2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2019-06-25 15:57:36.0",
#             "programCode": [
#                 "006:004"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "American Community Survey: 1-Year Estimates: Detailed Tables 1-Year"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "acs",
#                 "acs1",
#                 "cprofile"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/acs/acs1/cprofile/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/acs/acs1/cprofile/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/acs/acs1/cprofile/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_isCube": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/acs/acs1/cprofile/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/acs/acs1/cprofile/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "American Community Survey Office",
#                 "hasEmail": "mailto:acso.users.support@census.gov"
#             },
#             "description": "The American Community Survey (ACS) is an ongoing survey that provides data every year -- giving communities the current information they need to plan investments and services. The ACS covers a broad range of topics about social, economic, demographic, and housing characteristics of the U.S. population. Much of the ACS data provided on the Census Bureau's Web site are available separately by age group, race, Hispanic origin, and sex.  Summary files, Subject tables, Data profiles, and Comparison profiles are available for the nation, all 50 states, the District of Columbia, Puerto Rico, every congressional district, every metropolitan area, and all counties and places with populations of 65,000 or more.  Comparison profiles are similar to data profiles but also include comparisons with past-year data.  The current year data are compared with each of the last four years of data and include statistical significance testing.  There are over 1,000 variables in this dataset.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/acs/acs1/cprofile",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/ACSCP1Y2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2019-07-15 09:36:24.0",
#             "programCode": [
#                 "006:004"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "American Community Survey: 1-Year Estimates: Comparison Profiles 1-Year"
#         },
#         {
#             "@type": "dcat:Dataset",
#             "c_dataset": [
#                 "acs",
#                 "acs1",
#                 "profile"
#             ],
#             "c_documentationLink": "https://www.census.gov/developer/",
#             "c_examplesLink": "https://api.census.gov/data/2018/acs/acs1/profile/examples.json",
#             "c_geographyLink": "https://api.census.gov/data/2018/acs/acs1/profile/geography.json",
#             "c_groupsLink": "https://api.census.gov/data/2018/acs/acs1/profile/groups.json",
#             "c_isAggregate": true,
#             "c_isAvailable": true,
#             "c_isCube": true,
#             "c_valuesLink": "https://api.census.gov/data/2018/acs/acs1/profile/values.json",
#             "c_variablesLink": "https://api.census.gov/data/2018/acs/acs1/profile/variables.json",
#             "c_vintage": 2018,
#             "contactPoint": {
#                 "fn": "American Community Survey Office",
#                 "hasEmail": "mailto:acso.users.support@census.gov"
#             },
#             "description": "The American Community Survey (ACS) is an ongoing survey that provides data every year -- giving communities the current information they need to plan investments and services. The ACS covers a broad range of topics about social, economic, demographic, and housing characteristics of the U.S. population. Much of the ACS data provided on the Census Bureau's Web site are available separately by age group, race, Hispanic origin, and sex.  Summary files, Subject tables, Data profiles, and Comparison profiles are available for the nation, all 50 states, the District of Columbia, Puerto Rico, every congressional district, every metropolitan area, and all counties and places with populations of 65,000 or more.  Data profiles contain broad social, economic, housing, and demographic information. The data are presented as population counts and percentages. There are over 1,000 variables in this dataset.",
#             "distribution": [
#                 {
#                     "@type": "dcat:Distribution",
#                     "accessURL": "https://api.census.gov/data/2018/acs/acs1/profile",
#                     "description": "API endpoint",
#                     "format": "API",
#                     "mediaType": "application/json",
#                     "title": "API endpoint"
#                 }
#             ],
#             "identifier": "https://api.census.gov/data/id/ACSDP1Y2018",
#             "keyword": [],
#             "license": "https://creativecommons.org/publicdomain/zero/1.0/",
#             "modified": "2019-06-25 15:57:43.0",
#             "programCode": [
#                 "006:004"
#             ],
#             "publisher": {
#                 "@type": "org:Organization",
#                 "name": "U.S. Census Bureau",
#                 "subOrganizationOf": {
#                     "@type": "org:Organization",
#                     "name": "U.S. Department Of Commerce",
#                     "subOrganizationOf": {
#                         "@type": "org:Organization",
#                         "name": "U.S. Government"
#                     }
#                 }
#             },
#             "references": [
#                 "https://www.census.gov/developers/"
#             ],
#             "temporal": "unidentified",
#             "title": "ACS 1-Year Profile Tables"
#         }
#     ],
#     "describedBy": "https://project-open-data.cio.gov/v1.1/schema/catalog.json"
# }

# %%
data = response.json()
pprint(data)
# Out:
# {'@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@id': 'https://api.census.gov/data/2018/intltrade/imp_exp.json',
#  '@type': 'dcat:Catalog',
#  'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'dataset': [{'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['intltrade', 'imp_exp'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/intltrade/imp_exp/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/intltrade/imp_exp/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/intltrade/imp_exp/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/intltrade/imp_exp/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/intltrade/imp_exp/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Foreign Trade Staff',
#                                'hasEmail': 'EID.International.Trade.Data@census.gov'},
#               'description': 'This international trade file provides the '
#                              'annual dollar value of U.S. exports and imports '
#                              'of goods for all U.S. trade partners.  It also '
#                              'provides the annual dollar value of U.S. exports '
#                              'and imports of manufactured goods for all U.S. '
#                              'trade partners.  You can find this data and more '
#                              'by going to usatrade.census.gov.  If you have '
#                              'any questions regarding U.S. international trade '
#                              'data, please call us at 1(800)549-0595 option #4 '
#                              'or email us at '
#                              'eid.international.trade.data@census.gov.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/intltrade/imp_exp',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/ftd18ImpExpHist',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2019-03-13',
#               'programCode': ['000:000'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '2018/2018',
#               'title': '2018 International Trade: Historical Imports and '
#                        'Exports'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['pdb', 'blockgroup'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pdb/blockgroup/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pdb/blockgroup/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pdb/blockgroup/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_tagsLink': 'https://api.census.gov/data/2018/pdb/blockgroup/tags.json',
#               'c_valuesLink': 'https://api.census.gov/data/2018/pdb/blockgroup/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pdb/blockgroup/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Planning Database questions',
#                                'hasEmail': 'census.pdb.questions@census.gov'},
#               'description': 'The PDB is a database of U.S. housing, '
#                              'demographic, socioeconomic and operational '
#                              'statistics based on select 2010 Decennial Census '
#                              'and select  5-year American Community Survey '
#                              '(ACS) estimates. Data are provided at the census '
#                              'block group level of geography. These data can '
#                              'be used for many purposes, including survey '
#                              'field operations planning.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pdb/blockgroup',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/PDBBLOCKGROUP2018',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2018-07-19',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '2018/2018',
#               'title': '2018 Census Planning Database: Block Group'},
#              {'@type': 'dcat:Dataset',
#               'accessLevel': 'public',
#               'bureauCode': ['006:07'],
#               'c_dataset': ['pdb', 'tract'],
#               'c_documentationLink': 'http://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pdb/tract/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pdb/tract/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pdb/tract/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_tagsLink': 'https://api.census.gov/data/2018/pdb/tract/tags.json',
#               'c_valuesLink': 'https://api.census.gov/data/2018/pdb/tract/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pdb/tract/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Planning Database questions',
#                                'hasEmail': 'census.pdb.questions@census.gov'},
#               'description': 'The PDB is a database of U.S. housing, '
#                              'demographic, socioeconomic and operational '
#                              'statistics based on select 2010 Decennial Census '
#                              'and select  5-year American Community Survey '
#                              '(ACS) estimates. Data are provided at the census '
#                              'tract level of geography. These data can be used '
#                              'for many purposes, including survey field '
#                              'operations planning.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pdb/tract',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'http://api.census.gov/data/id/PDBTRACT2018',
#               'keyword': [],
#               'license': 'http://creativecommons.org/publicdomain/zero/1.0/Public '
#                          'Domain',
#               'modified': '2018-07-19',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['http://www.census.gov/developers/'],
#               'spatial': 'United States',
#               'temporal': '2018/2018',
#               'title': '2018 Census Planning Database: Tract Level'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['pep', 'natmonthly'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pep/natmonthly/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pep/natmonthly/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pep/natmonthly/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/pep/natmonthly/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pep/natmonthly/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'pop.population.estimates@census.gov'},
#               'description': 'Monthly Population Estimates by Universe, Age, '
#                              'Sex, Race, and Hispanic Origin for the United '
#                              'States: April 1, 2010 to December 1, 2018 // '
#                              'Source: U.S. Census Bureau, Population Division '
#                              '// The contents of this file are released on a '
#                              'rolling basis from December through June. // '
#                              "Note: 'In combination' means in combination with "
#                              'one or more other races. The sum of the five '
#                              'race-in-combination groups adds to more than the '
#                              'total population because individuals may report '
#                              'more than one race. Hispanic origin is '
#                              'considered an ethnicity, not a race. Hispanics '
#                              "may be of any race. Responses of 'Some Other "
#                              "Race' from the 2010 Census are modified. This "
#                              'results in differences between the population '
#                              'for specific race categories shown for the 2010 '
#                              'Census population in this file versus those in '
#                              'the original 2010 Census data. For more '
#                              'information, see '
#                              'https://www2.census.gov/programs-surveys/popest/technical-documentation/methodology/modified-race-summary-file-method/mrsf2010.pdf. '
#                              '// The estimates are based on the 2010 Census '
#                              'and reflect changes to the April 1, 2010 '
#                              'population due to the Count Question Resolution '
#                              'program and geographic program revisions. // '
#                              'Persons on active duty in the Armed Forces were '
#                              'not enumerated in the 2010 Census. Therefore, '
#                              'variables for the 2010 Census civilian, civilian '
#                              'noninstitutionalized, and resident population '
#                              'plus Armed Forces overseas populations cannot be '
#                              'derived and are not available on these files. // '
#                              'For detailed information about the methods used '
#                              'to create the population estimates, see '
#                              'https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. '
#                              "// Each year, the Census Bureau's Population "
#                              'Estimates Program (PEP) utilizes current data on '
#                              'births, deaths, and migration to calculate '
#                              'population change since the most recent '
#                              'decennial census, and produces a time series of '
#                              'estimates of population. The annual time series '
#                              'of estimates begins with the most recent '
#                              'decennial census data and extends to the vintage '
#                              'year. The vintage year (e.g., V2017) refers to '
#                              'the final year of the time series. The reference '
#                              'date for all estimates is July 1, unless '
#                              'otherwise specified. With each new issue of '
#                              'estimates, the Census Bureau revises estimates '
#                              'for years back to the last census. As each '
#                              'vintage of estimates includes all years since '
#                              'the most recent decennial census, the latest '
#                              'vintage of data available supersedes all '
#                              'previously produced estimates for those dates. '
#                              'The Population Estimates Program provides '
#                              'additional information including historical and '
#                              'intercensal estimates, evaluation estimates, '
#                              'demographic analysis, and research papers on its '
#                              'website: '
#                              'https://www.census.gov/programs-surveys/popest.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pep/natmonthly',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/PEPNATMONTHLY2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/unidentified',
#               'modified': '2018-12-10 00:00:00.0',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Vintage 2018 Population Estimates: National Monthly '
#                        'Population Estimates'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['pep', 'charage'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pep/charage/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pep/charage/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pep/charage/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/pep/charage/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pep/charage/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'mailto:pop.population.estimates@census.gov'},
#               'description': 'Annual Resident Population Estimates by Single '
#                              'Year of Age, Sex, Race, and Hispanic Origin // '
#                              'Source: U.S. Census Bureau, Population Division '
#                              "// Note: 'In combination' means in combination "
#                              'with one or more other races. The sum of the '
#                              'five race-in-combination groups adds to more '
#                              'than the total population because individuals '
#                              'may report more than one race. Hispanic origin '
#                              'is considered an ethnicity, not a race. '
#                              "Hispanics may be of any race. Responses of 'Some "
#                              "Other Race' from the 2010 Census are modified. "
#                              'This results in differences between the '
#                              'population for specific race categories shown '
#                              'for the 2010 Census population in this file '
#                              'versus those in the original 2010 Census data.  '
#                              '// The estimates are based on the 2010 Census '
#                              'and reflect changes to the April 1, 2010 '
#                              'population due to the Count Question Resolution '
#                              'program and geographic program revisions. // The '
#                              'vintage year refers to the final year of the '
#                              'time series. Each vintage of estimates includes '
#                              'all years since the most recent decennial '
#                              'census.  The latest vintage estimates supersede '
#                              'all previous vintage estimates. More information '
#                              'about the Population Estimates Program, '
#                              'methodologies, and other products are available '
#                              'at '
#                              'https://www.census.gov/programs-surveys/popest.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pep/charage',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/PEPCHARAGE2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-03-13 00:00:00.0',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Vintage 2018 Population Estimates: Characteristics by '
#                        'Single Year of Age'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['pep', 'charagegroups'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pep/charagegroups/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pep/charagegroups/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pep/charagegroups/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/pep/charagegroups/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pep/charagegroups/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'mailto:pop.population.estimates@census.gov'},
#               'description': 'Annual Resident Population Estimates by Age '
#                              'Group, Sex, Race, and Hispanic Origin: April 1, '
#                              '2010 to July 1, 2018 // Source: U.S. Census '
#                              'Bureau, Population Division // The contents of '
#                              'this file are released on a rolling basis from '
#                              "December through June. // Note: 'In combination' "
#                              'means in combination with one or more other '
#                              'races. The sum of the five race-in-combination '
#                              'groups adds to more than the total population '
#                              'because individuals may report more than one '
#                              'race. Hispanic origin is considered an '
#                              'ethnicity, not a race. Hispanics may be of any '
#                              "race. Responses of 'Some Other Race' from the "
#                              '2010 Census are modified. This results in '
#                              'differences between the population for specific '
#                              'race categories shown for the 2010 Census '
#                              'population in this file versus those in the '
#                              'original 2010 Census data. For more information, '
#                              'see '
#                              'https://www2.census.gov/programs-surveys/popest/technical-documentation/methodology/modified-race-summary-file-method/mrsf2010.pdf. '
#                              '// The estimates are based on the 2010 Census '
#                              'and reflect changes to the April 1, 2010 '
#                              'population due to the Count Question Resolution '
#                              'program and geographic program revisions. // For '
#                              'detailed information about the methods used to '
#                              'create the population estimates, see '
#                              'https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. '
#                              "// Each year, the Census Bureau's Population "
#                              'Estimates Program (PEP) utilizes current data on '
#                              'births, deaths, and migration to calculate '
#                              'population change since the most recent '
#                              'decennial census, and produces a time series of '
#                              'estimates of population. The annual time series '
#                              'of estimates begins with the most recent '
#                              'decennial census data and extends to the vintage '
#                              'year. The vintage year (e.g., V2017) refers to '
#                              'the final year of the time series. The reference '
#                              'date for all estimates is July 1, unless '
#                              'otherwise specified. With each new issue of '
#                              'estimates, the Census Bureau revises estimates '
#                              'for years back to the last census. As each '
#                              'vintage of estimates includes all years since '
#                              'the most recent decennial census, the latest '
#                              'vintage of data available supersedes all '
#                              'previously produced estimates for those dates. '
#                              'The Population Estimates Program provides '
#                              'additional information including historical and '
#                              'intercensal estimates, evaluation estimates, '
#                              'demographic analysis, and research papers on its '
#                              'website: '
#                              'https://www.census.gov/programs-surveys/popest.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pep/charagegroups',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/PEPCHARAGEGROUPS2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2018-12-10 00:00:00.0',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Vintage 2018 Population Estimates: Demographic '
#                        'Characteristics Estimates by Age Groups'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['pep', 'population'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pep/population/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pep/population/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pep/population/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/pep/population/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pep/population/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'mailto:pop.population.estimates@census.gov'},
#               'description': 'Annual Population Estimates for the United '
#                              'States; States; Metropolitan Statistical Areas, '
#                              'Micropolitan Statistical Areas, and Related '
#                              'Statistical Areas; Counties; and Subcounty '
#                              'Places; and for Puerto Rico and Its Municipios: '
#                              'April 1, 2010 to July 1, 2018 // Source: U.S. '
#                              'Census Bureau, Population Division // The '
#                              'contents of this file are released on a rolling '
#                              'basis from December through May. // Note: The '
#                              'estimates are based on the 2010 Census and '
#                              'reflect changes to the April 1, 2010 population '
#                              'due to the Count Question Resolution program and '
#                              'geographic program revisions. // The Office of '
#                              "Management and Budget's statistical area "
#                              'delineations for metropolitan, micropolitan, and '
#                              'combined statistical areas, as well as '
#                              'metropolitan divisions, are those issued by that '
#                              'agency in July 2015. // The 2010 Census did not '
#                              'ascertain the military status of the household '
#                              'population. Therefore, variables for the 2010 '
#                              'Census civilian, civilian noninstitutionalized, '
#                              'and resident population plus Armed Forces '
#                              'overseas populations cannot be derived and are '
#                              'not available on this file. // For detailed '
#                              'information about the methods used to create the '
#                              'population estimates, see '
#                              'https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. '
#                              "// Each year, the Census Bureau's Population "
#                              'Estimates Program (PEP) utilizes current data on '
#                              'births, deaths, and migration to calculate '
#                              'population change since the most recent '
#                              'decennial census, and produces a time series of '
#                              'estimates of population. The annual time series '
#                              'of estimates begins with the most recent '
#                              'decennial census data and extends to the vintage '
#                              'year. The vintage year (e.g., Vintage 2017) '
#                              'refers to the final year of the time series. The '
#                              'reference date for all estimates is July 1, '
#                              'unless otherwise specified. With each new issue '
#                              'of estimates, the Census Bureau revises '
#                              'estimates for years back to the last census. As '
#                              'each vintage of estimates includes all years '
#                              'since the most recent decennial census, the '
#                              'latest vintage of data available supersedes all '
#                              'previously produced estimates for those dates. '
#                              'The Population Estimates Program provides '
#                              'additional information including historical and '
#                              'intercensal estimates, evaluation estimates, '
#                              'demographic analysis, and research papers on its '
#                              'website: '
#                              'https://www.census.gov/programs-surveys/popest.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pep/population',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/PEPPOP2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2018-12-10 00:00:00.0',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Vintage 2018 Population Estimates: Population '
#                        'Estimates'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['pep', 'components'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pep/components/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pep/components/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pep/components/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/pep/components/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pep/components/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'mailto:pop.population.estimates@census.gov'},
#               'description': 'Annual Resident Population Estimates, Estimated '
#                              'Components of Resident Population Change, and '
#                              'Rates of the Components of Resident Population '
#                              'Change: April 1, 2010 to July 1, 2018 // Source: '
#                              'U.S. Census Bureau, Population Division // The '
#                              'contents of this file are released on a rolling '
#                              'basis from December through March. // Note: '
#                              'Total population change includes a residual. '
#                              'This residual represents the change in '
#                              'population that cannot be attributed to any '
#                              'specific demographic component. See the '
#                              'Population Estimates Glossary at '
#                              'https://www.census.gov/programs-surveys/popest/about/glossary.html. '
#                              '// Net international migration in the United '
#                              'States includes the international migration of '
#                              'both native and foreign-born populations. '
#                              'Specifically, it includes: (a) the net '
#                              'international migration of the foreign born, (b) '
#                              'the net migration between the United States and '
#                              'Puerto Rico, (c) the net migration of natives to '
#                              'and from the United States, and (d) the net '
#                              'movement of the Armed Forces population between '
#                              'the United States and overseas. // The estimates '
#                              'are based on the 2010 Census and reflect changes '
#                              'to the April 1, 2010 population due to the Count '
#                              'Question Resolution program.// The Office of '
#                              "Management and Budget's statistical area "
#                              'delineations for metropolitan, micropolitan, and '
#                              'combined statistical areas, as well as '
#                              'metropolitan divisions, are those issued by that '
#                              'agency in July 2015. // For detailed information '
#                              'about the methods used to create the population '
#                              'estimates, see '
#                              'https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html. '
#                              "// Each year, the Census Bureau's Population "
#                              'Estimates Program (PEP) utilizes current data on '
#                              'births, deaths, and migration to calculate '
#                              'population change since the most recent '
#                              'decennial census, and produces a time series of '
#                              'estimates of population. The annual time series '
#                              'of estimates begins with the most recent '
#                              'decennial census data and extends to the vintage '
#                              'year. The vintage year (e.g., Vintage 2018) '
#                              'refers to the final year of the time series. The '
#                              'reference date for all estimates is July 1, '
#                              'unless otherwise specified. With each new issue '
#                              'of estimates, the Census Bureau revises '
#                              'estimates for years back to the last census. As '
#                              'each vintage of estimates includes all years '
#                              'since the most recent decennial census, the '
#                              'latest vintage of data available supersedes all '
#                              'previously produced estimates for those dates. '
#                              'The Population Estimates Program provides '
#                              'additional information including historical and '
#                              'intercensal estimates, evaluation estimates, '
#                              'demographic analysis, and research papers on its '
#                              'website: '
#                              'https://www.census.gov/programs-surveys/popest.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pep/components',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/PEPCOMPONENTS2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2018-12-10 00:00:00.0',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Vintage 2018 Population Estimates: Components of '
#                        'Change Estimates'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['pep', 'housing'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/pep/housing/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/pep/housing/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/pep/housing/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/pep/housing/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/pep/housing/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'Population Estimates Branch',
#                                'hasEmail': 'mailto:pop.population.estimates@census.gov'},
#               'description': 'Annual Housing Unit Estimates for the United '
#                              'States, States, and Counties // Source: U.S. '
#                              'Census Bureau, Population Division // Note: The '
#                              'estimates are based on the 2010 Census and '
#                              'reflect changes to the April 1, 2010 housing '
#                              'units due to the Count Question Resolution '
#                              'program and geographic program revisions. For '
#                              'the housing unit estimates methodology '
#                              'statement, see '
#                              'https://www.census.gov/programs-surveys/popest/technical-documentation/methodology.html.// '
#                              "Each year, the Census Bureau's Population and "
#                              'Housing Unit Estimates Program utilizes current '
#                              'data on new residential construction, placements '
#                              'of manufactured housing, and housing unit loss '
#                              'to calculate change in the housing stock since '
#                              'the most recent decennial census, and produces a '
#                              'time series of housing unit estimates.. The '
#                              'annual time series of estimates begins with the '
#                              'most recent decennial census data and extends to '
#                              'the vintage year. The vintage year (e.g., V2018) '
#                              'refers to the final year of the time series. The '
#                              'reference date for all estimates is July 1, '
#                              'unless otherwise specified. With each new issue '
#                              'of estimates, the Census Bureau revises '
#                              'estimates for years back to the last census. As '
#                              'each vintage of estimates includes all years '
#                              'since the most recent decennial census, the '
#                              'latest vintage of data available supersedes all '
#                              'previously produced estimates for those dates. '
#                              'The Population and Housing Unit Estimates '
#                              'Program provides additional information '
#                              'including population estimates, historical and '
#                              'intercensal estimates, evaluation estimates, '
#                              'demographic analysis, and research papers on its '
#                              'website: '
#                              'https://www.census.gov/programs-surveys/popest.html.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/pep/housing',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/PEPHOUSING2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-05-23 16:55:50.0',
#               'programCode': ['006:008'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'Vintage 2018 Population Estimates: Housing Unit '
#                        'Estimates for US, States, and Counties'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['acs', 'acs1'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/acs/acs1/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/acs/acs1/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/acs/acs1/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_tagsLink': 'https://api.census.gov/data/2018/acs/acs1/tags.json',
#               'c_valuesLink': 'https://api.census.gov/data/2018/acs/acs1/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/acs/acs1/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'American Community Survey Office',
#                                'hasEmail': 'mailto:acso.users.support@census.gov'},
#               'description': 'The American Community Survey (ACS) is an '
#                              'ongoing survey that provides data every year -- '
#                              'giving communities the current information they '
#                              'need to plan investments and services. The ACS '
#                              'covers a broad range of topics about social, '
#                              'economic, demographic, and housing '
#                              'characteristics of the U.S. population. Much of '
#                              "the ACS data provided on the Census Bureau's Web "
#                              'site are available separately by age group, '
#                              'race, Hispanic origin, and sex.  Summary files, '
#                              'Subject tables, Data profiles, and Comparison '
#                              'profiles are available for the nation, all 50 '
#                              'states, the District of Columbia, Puerto Rico, '
#                              'every congressional district, every metropolitan '
#                              'area, and all counties and places with '
#                              'populations of 65,000 or more.  Detail Tables '
#                              'contain the most detailed cross-tabulations '
#                              'published for areas 65k and more. The data are '
#                              'population counts. There are over 31,000 '
#                              'variables in this dataset.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/acs/acs1',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/ACSDT1Y2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-06-25 15:57:36.0',
#               'programCode': ['006:004'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'American Community Survey: 1-Year Estimates: Detailed '
#                        'Tables 1-Year'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['acs', 'acs1', 'cprofile'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/acs/acs1/cprofile/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/acs/acs1/cprofile/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/acs/acs1/cprofile/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/acs/acs1/cprofile/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/acs/acs1/cprofile/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'American Community Survey Office',
#                                'hasEmail': 'mailto:acso.users.support@census.gov'},
#               'description': 'The American Community Survey (ACS) is an '
#                              'ongoing survey that provides data every year -- '
#                              'giving communities the current information they '
#                              'need to plan investments and services. The ACS '
#                              'covers a broad range of topics about social, '
#                              'economic, demographic, and housing '
#                              'characteristics of the U.S. population. Much of '
#                              "the ACS data provided on the Census Bureau's Web "
#                              'site are available separately by age group, '
#                              'race, Hispanic origin, and sex.  Summary files, '
#                              'Subject tables, Data profiles, and Comparison '
#                              'profiles are available for the nation, all 50 '
#                              'states, the District of Columbia, Puerto Rico, '
#                              'every congressional district, every metropolitan '
#                              'area, and all counties and places with '
#                              'populations of 65,000 or more.  Comparison '
#                              'profiles are similar to data profiles but also '
#                              'include comparisons with past-year data.  The '
#                              'current year data are compared with each of the '
#                              'last four years of data and include statistical '
#                              'significance testing.  There are over 1,000 '
#                              'variables in this dataset.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/acs/acs1/cprofile',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/ACSCP1Y2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-07-15 09:36:24.0',
#               'programCode': ['006:004'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'American Community Survey: 1-Year Estimates: '
#                        'Comparison Profiles 1-Year'},
#              {'@type': 'dcat:Dataset',
#               'c_dataset': ['acs', 'acs1', 'profile'],
#               'c_documentationLink': 'https://www.census.gov/developer/',
#               'c_examplesLink': 'https://api.census.gov/data/2018/acs/acs1/profile/examples.json',
#               'c_geographyLink': 'https://api.census.gov/data/2018/acs/acs1/profile/geography.json',
#               'c_groupsLink': 'https://api.census.gov/data/2018/acs/acs1/profile/groups.json',
#               'c_isAggregate': True,
#               'c_isAvailable': True,
#               'c_isCube': True,
#               'c_valuesLink': 'https://api.census.gov/data/2018/acs/acs1/profile/values.json',
#               'c_variablesLink': 'https://api.census.gov/data/2018/acs/acs1/profile/variables.json',
#               'c_vintage': 2018,
#               'contactPoint': {'fn': 'American Community Survey Office',
#                                'hasEmail': 'mailto:acso.users.support@census.gov'},
#               'description': 'The American Community Survey (ACS) is an '
#                              'ongoing survey that provides data every year -- '
#                              'giving communities the current information they '
#                              'need to plan investments and services. The ACS '
#                              'covers a broad range of topics about social, '
#                              'economic, demographic, and housing '
#                              'characteristics of the U.S. population. Much of '
#                              "the ACS data provided on the Census Bureau's Web "
#                              'site are available separately by age group, '
#                              'race, Hispanic origin, and sex.  Summary files, '
#                              'Subject tables, Data profiles, and Comparison '
#                              'profiles are available for the nation, all 50 '
#                              'states, the District of Columbia, Puerto Rico, '
#                              'every congressional district, every metropolitan '
#                              'area, and all counties and places with '
#                              'populations of 65,000 or more.  Data profiles '
#                              'contain broad social, economic, housing, and '
#                              'demographic information. The data are presented '
#                              'as population counts and percentages. There are '
#                              'over 1,000 variables in this dataset.',
#               'distribution': [{'@type': 'dcat:Distribution',
#                                 'accessURL': 'https://api.census.gov/data/2018/acs/acs1/profile',
#                                 'description': 'API endpoint',
#                                 'format': 'API',
#                                 'mediaType': 'application/json',
#                                 'title': 'API endpoint'}],
#               'identifier': 'https://api.census.gov/data/id/ACSDP1Y2018',
#               'keyword': [],
#               'license': 'https://creativecommons.org/publicdomain/zero/1.0/',
#               'modified': '2019-06-25 15:57:43.0',
#               'programCode': ['006:004'],
#               'publisher': {'@type': 'org:Organization',
#                             'name': 'U.S. Census Bureau',
#                             'subOrganizationOf': {'@type': 'org:Organization',
#                                                   'name': 'U.S. Department Of '
#                                                           'Commerce',
#                                                   'subOrganizationOf': {'@type': 'org:Organization',
#                                                                         'name': 'U.S. '
#                                                                                 'Government'}}},
#               'references': ['https://www.census.gov/developers/'],
#               'temporal': 'unidentified',
#               'title': 'ACS 1-Year Profile Tables'}],
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json'}

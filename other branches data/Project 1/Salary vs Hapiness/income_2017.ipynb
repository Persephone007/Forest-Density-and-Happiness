# %%
# Dependencies
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Save path to data set in a variable
data_file = "Resources/county_data2017.csv"

# %%
# Use Pandas to read data
data_file_df = pd.read_csv(data_file)
data_file_df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
# Display a statistical overview of the DataFrame
data_file_df.describe()
# Out:
#            CountyId      TotalPop           Men         Women     Hispanic  \
# count   3220.000000  3.220000e+03  3.220000e+03  3.220000e+03  3220.000000
# mean   31393.605280  1.007681e+05  4.958781e+04  5.118032e+04    11.296584
# std    16292.078954  3.244996e+05  1.593212e+05  1.652164e+05    19.342522
# min     1001.000000  7.400000e+01  3.900000e+01  3.500000e+01     0.000000
# 25%    19032.500000  1.121350e+04  5.645500e+03  5.553500e+03     2.100000
# 50%    30024.000000  2.584750e+04  1.287900e+04  1.299350e+04     4.100000
# 75%    46105.500000  6.660825e+04  3.301725e+04  3.359375e+04    10.000000
# max    72153.000000  1.010572e+07  4.979641e+06  5.126081e+06   100.000000
#
#              White        Black       Native        Asian      Pacific  ...  \
# count  3220.000000  3220.000000  3220.000000  3220.000000  3220.000000  ...
# mean     74.920186     8.681957     1.768416     1.289379     0.083416  ...
# ...

# %%
# Reference multiple columns within a DataFrame
new_data_df=data_file_df[["State", "County","Income"]]
new_data_df
# Out:
#             State                   County  Income
# 0         Alabama           Autauga County   55317
# 1         Alabama           Baldwin County   52562
# 2         Alabama           Barbour County   33368
# 3         Alabama              Bibb County   43404
# 4         Alabama            Blount County   47412
# 5         Alabama           Bullock County   29655
# 6         Alabama            Butler County   36326
# 7         Alabama           Calhoun County   43686
# 8         Alabama          Chambers County   37342
# 9         Alabama          Cherokee County   40041
# 10        Alabama           Chilton County   43501
# 11        Alabama           Choctaw County   32122
# 12        Alabama            Clarke County   33827
# 13        Alabama              Clay County   37287
# 14        Alabama          Cleburne County   37396
# 15        Alabama            Coffee County   49821
# 16        Alabama           Colbert County   45477
# ...

# %%
new_data_df.to_csv("Output/2017_newdata.csv", index=True, header=True)

# %%
new_data_df['County'].unique()
# Out:
# array(['Autauga County', 'Baldwin County', 'Barbour County', ...,
#        'Villalba Municipio', 'Yabucoa Municipio', 'Yauco Municipio'],
#       dtype=object)

# %%
round(new_data_df.groupby('County')['Income'].mean(),2)
# Out:
# County
# Abbeville County              35254.00
# Acadia Parish                 40492.00
# Accomack County               42260.00
# Ada County                    60151.00
# Adair County                  39542.00
# Adams County                  48433.17
# Addison County                61875.00
# Adjuntas Municipio            11680.00
# Aguada Municipio              16199.00
# Aguadilla Municipio           16821.00
# Aguas Buenas Municipio        16733.00
# Aibonito Municipio            18387.00
# Aiken County                  47713.00
# Aitkin County                 45860.00
# Alachua County                45478.00
# Alamance County               44281.00
# Alameda County                85743.00
# Alamosa County                36315.00
# Albany County                 54054.50
# Albemarle County              72265.00
# Alcona County                 39424.00
# Alcorn County                 38919.00
# Aleutians East Borough        66607.00
# Aleutians West Census Area    85192.00
# ...

# %%
new_data_df['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
round(new_data_df.groupby('State')['Income'].mean(),2)
# Out:
# State
# Alabama                 40271.40
# Alaska                  66425.45
# Arizona                 45816.67
# Arkansas                39025.08
# California              61046.76
# Colorado                54353.56
# Connecticut             74496.00
# Delaware                61294.67
# District of Columbia    77649.00
# Florida                 47144.33
# Georgia                 43268.79
# Hawaii                  68663.00
# Idaho                   46171.93
# Illinois                52930.38
# Indiana                 51877.40
# Iowa                    53436.08
# Kansas                  50022.57
# Kentucky                41470.49
# Louisiana               42654.08
# Maine                   49680.81
# Maryland                72541.17
# Massachusetts           71030.71
# Michigan                47530.52
# Minnesota               57530.00
# Mississippi             37018.72
# Missouri                44435.30
# Montana                 47746.75
# Nebraska                51928.35
# ...

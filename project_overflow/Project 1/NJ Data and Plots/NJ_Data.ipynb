# %%
#Dependencies 
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as n
forest_data = "forest_fips.csv"
full_data = "full_data_csv.csv"
age_data = "Health_Data_CSV.csv"
forest_data_df = pd.read_csv(forest_data)
full_data_df = pd.read_csv(full_data)
age_data_df = pd.read_csv(age_data)

# %%
NJ_data = "NJ_Specific_CSV.csv"
NJ_data_df = pd.read_csv(NJ_data)
NJ_data_df.head()
# Out:
#       FIPS       State      County  Years of Potential Life Lost Rate  \
# 0  34001.0  New Jersey    Atlantic                             8541.0
# 1  34003.0  New Jersey      Bergen                             3836.0
# 2  34005.0  New Jersey  Burlington                             6302.0
# 3  34007.0  New Jersey      Camden                             8246.0
# 4  34009.0  New Jersey    Cape May                             8617.0
#
#    95% CI - Low  95% CI - High  Z-Score  YPLL Rate (Black)  \
# 0        8131.0         8952.0     1.30            14290.0
# 1        3695.0         3976.0    -1.46             5853.0
# 2        6028.0         6575.0    -0.01             7764.0
# 3        7956.0         8536.0     1.13            12457.0
# 4        7866.0         9368.0     1.34            10720.0
#
#    YPLL Rate (Hispanic)  YPLL Rate (White)  ...  95% CI - High.17  Z-Score.33  \
# 0                5954.0             8845.0  ...              78.0        0.18
# ...

# %%
forest_college_df = pd.merge(forest_data_df,full_data_df, on="FIPS")
forest_college_df.head()
# Out:
#   State_x County_x  Mapping Zones  Tree Canopy Cover %  \
# 0      AL  Autauga             46             0.567194
# 1      AL  Baldwin             46             0.575551
# 2      AL  Barbour             46             0.605966
# 3      AL     Bibb             48             0.715375
# 4      AL   Blount             48             0.429399
#
#    Tree Canopy Cover (m2/person)  Total Green Space (ha)  FIPS  State_y  \
# 0                    20026.33290             152866.9952  1001  Alabama
# 1                    16979.38254             409233.9968  1003  Alabama
# 2                    47623.45836             226867.9936  1005  Alabama
# 3                    55289.06098             160413.0048  1007  Alabama
# 4                    14043.19599             165458.9952  1009  Alabama
#
#   County_y  # Some College  Population  % Some College  Income Ratio  \
# 0  Autauga            8701       14298              61           4.6
# ...

# %%
NJ_forest_college_df = pd.merge(NJ_data_df,forest_college_df, on="FIPS")
NJ_forest_college_df
# Out:
#        FIPS       State      County  Years of Potential Life Lost Rate  \
# 0   34001.0  New Jersey    Atlantic                             8541.0
# 1   34003.0  New Jersey      Bergen                             3836.0
# 2   34005.0  New Jersey  Burlington                             6302.0
# 3   34007.0  New Jersey      Camden                             8246.0
# 4   34009.0  New Jersey    Cape May                             8617.0
# 5   34011.0  New Jersey  Cumberland                             9449.0
# 6   34013.0  New Jersey       Essex                             7240.0
# 7   34015.0  New Jersey  Gloucester                             6931.0
# 8   34017.0  New Jersey      Hudson                             5064.0
# 9   34019.0  New Jersey   Hunterdon                             4499.0
# 10  34021.0  New Jersey      Mercer                             6066.0
# 11  34023.0  New Jersey   Middlesex                             4569.0
# ...

# %%
plt.scatter(NJ_forest_college_df["Tree Canopy Cover (m2/person)"],NJ_forest_college_df["% Some College_y"], 
           label = "% Some College vs Tree Canopy Cover (m2/person) in NJ")
plt.title("% Some College vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("% Some College")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('college.jpg')

# %%
forest_full_df = pd.merge(forest_data_df,full_data_df, on="FIPS")
forest_full_df.head()
# Out:
#   State_x County_x  Mapping Zones  Tree Canopy Cover %  \
# 0      AL  Autauga             46             0.567194
# 1      AL  Baldwin             46             0.575551
# 2      AL  Barbour             46             0.605966
# 3      AL     Bibb             48             0.715375
# 4      AL   Blount             48             0.429399
#
#    Tree Canopy Cover (m2/person)  Total Green Space (ha)  FIPS  State_y  \
# 0                    20026.33290             152866.9952  1001  Alabama
# 1                    16979.38254             409233.9968  1003  Alabama
# 2                    47623.45836             226867.9936  1005  Alabama
# 3                    55289.06098             160413.0048  1007  Alabama
# 4                    14043.19599             165458.9952  1009  Alabama
#
#   County_y  # Some College  Population  % Some College  Income Ratio  \
# 0  Autauga            8701       14298              61           4.6
# ...

# %%
NJ_forest_full_df = pd.merge(NJ_data_df,forest_full_df, on="FIPS")
NJ_forest_full_df.head()
# Out:
#       FIPS       State      County  Years of Potential Life Lost Rate  \
# 0  34001.0  New Jersey    Atlantic                             8541.0
# 1  34003.0  New Jersey      Bergen                             3836.0
# 2  34005.0  New Jersey  Burlington                             6302.0
# 3  34007.0  New Jersey      Camden                             8246.0
# 4  34009.0  New Jersey    Cape May                             8617.0
#
#    95% CI - Low  95% CI - High  Z-Score  YPLL Rate (Black)  \
# 0        8131.0         8952.0     1.30            14290.0
# 1        3695.0         3976.0    -1.46             5853.0
# 2        6028.0         6575.0    -0.01             7764.0
# 3        7956.0         8536.0     1.13            12457.0
# 4        7866.0         9368.0     1.34            10720.0
#
#    YPLL Rate (Hispanic)  YPLL Rate (White)  ...  Tree Canopy Cover %  \
# 0                5954.0             8845.0  ...             0.484206
# ...

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["% Unemployed"], 
           label = "% Unemployed vs Tree Canopy Cover (m2/person) in NJ")
plt.title("% Unemployed vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("% Unemployed")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('Unemployed.jpg')

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["Mentally Unhealthy Days"], 
           label = "Mentally Unhealthy Days vs Tree Canopy Cover (m2/person) in NJ")
plt.title("Mentally Unhealthy Days vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("Mentally Unhealthy Days")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('UnhealthyMental.jpg')

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["Physically Unhealthy Days"], 
           label = "Physically Unhealthy Days vs Tree Canopy Cover (m2/person) in NJ")
plt.title("Physically Unhealthy Days vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("Physically Unhealthy Days")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('Physicalhealth.jpg')

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["% Excessive Drinking"], 
           label = "% Excessive Drinking vs Tree Canopy Cover (m2/person) in NJ")
plt.title("% Excessive Drinking vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("% Excessive Drinking")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('ExcessDrinking.jpg')

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["% Children in Poverty"], 
           label = "% Children in Poverty vs Tree Canopy Cover (m2/person) in NJ")
plt.title("% Children in Poverty vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("% Children in Poverty")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('ChildrenInPoverty.jpg')

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["Association Rate"], 
           label = "Association Rate vs Tree Canopy Cover (m2/person) in NJ")
plt.title("Association Rate vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("Association Rate")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('AssociationRate')

# %%
plt.scatter(NJ_forest_full_df["Tree Canopy Cover (m2/person)"],NJ_forest_full_df["% Severe Housing Problems"], 
           label = "% Severe Housing Problems vs Tree Canopy Cover (m2/person) in NJ")
plt.title("% Severe Housing Problems vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("% Severe Housing Problems")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('HousingProbs.')

# %%
new_nj_df=NJ_data_df[["FIPS", "Violent Crime Rate","Income Ratio"]]
new_nj_df.head()
# Out:
#       FIPS  Violent Crime Rate  Income Ratio
# 0  34001.0               373.0           5.2
# 1  34003.0                84.0           5.0
# 2  34005.0               163.0           4.0
# 3  34007.0               465.0           5.4
# 4  34009.0               236.0           4.6

# %%
NJ_final_df = pd.merge(new_nj_df,forest_full_df, on="FIPS")
NJ_final_df.head()
# Out:
#       FIPS  Violent Crime Rate_x  Income Ratio_x State_x         County_x  \
# 0  34001.0                 373.0             5.2      NJ         Atlantic
# 1  34003.0                  84.0             5.0      NJ           Bergen
# 2  34005.0                 163.0             4.0      NJ       Burlington
# 3  34007.0                 465.0             5.4      NJ           Camden
# 4  34009.0                 236.0             4.6      NJ  Cape May County
#
#    Mapping Zones  Tree Canopy Cover %  Tree Canopy Cover (m2/person)  \
# 0             60             0.484206                    2791.892299
# 1             64             0.468554                     322.820040
# 2             60             0.454458                    2247.816455
# 3             60             0.366401                     415.839444
# 4             60             0.335119                    2173.748686
#
#    Total Green Space (ha)     State_y    County_y  # Some College  Population  \
# ...

# %%
plt.scatter(NJ_final_df["Tree Canopy Cover (m2/person)"],NJ_final_df["Violent Crime Rate_x"], 
           label = "Violent Crime Rate vs Tree Canopy Cover (m2/person) in NJ")
plt.title("Violent Crime Rate vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("Violent Crime Rate")

plt.show()

# %%
fig.savefig('CrimeRate')

# %%
plt.scatter(NJ_final_df["Tree Canopy Cover (m2/person)"],NJ_final_df["Income Ratio_x"], 
           label = "Income Ratio vs Tree Canopy Cover (m2/person) in NJ")
plt.title("Income Ratio vs Tree Canopy Cover (m2/person) in NJ")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("Income Ratio")

plt.show()

# %%
fig.savefig('IncomeRatio')

# %%
#  Dependencies
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
poverty_data = (r'C:\Users\lecha\Desktop\Forrest_Project\Charlene\NJ_graph.csv')
poverty_data_df = pd.read_csv(poverty_data)
poverty_data_df.head()
# Out:
#       FIPS       State      County  Years of Potential Life Lost Rate  \
# 0  34001.0  New Jersey    Atlantic                             8541.0
# 1  34003.0  New Jersey      Bergen                             3836.0
# 2  34005.0  New Jersey  Burlington                             6302.0
# 3  34007.0  New Jersey      Camden                             8246.0
# 4  34009.0  New Jersey    Cape May                             8617.0
#
#    95% CI - Low  95% CI - High  Z-Score  YPLL Rate (Black)  \
# 0        8131.0         8952.0     1.30            14290.0
# 1        3695.0         3976.0    -1.46             5853.0
# 2        6028.0         6575.0    -0.01             7764.0
# 3        7956.0         8536.0     1.13            12457.0
# 4        7866.0         9368.0     1.34            10720.0
#
#    YPLL Rate (Hispanic)  YPLL Rate (White)  ...  95% CI - High.17  Z-Score.33  \
# 0                5954.0             8845.0  ...              78.0        0.18
# ...

# %%
forest_data = (r'C:\Users\lecha\Desktop\Forrest_Project\Charlene\forest_fips.csv')
forest_data_df = pd.read_csv(forest_data)
forest_data_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 State   County  Mapping Zones  Impervious Cover %  \
# 0           0             3    AL  Autauga             46            0.008595
# 1           1             4    AL  Baldwin             46            0.012084
# 2           2             5    AL  Barbour             46            0.005891
# 3           3             6    AL     Bibb             48            0.003383
# 4           4             7    AL   Blount             48            0.008458
#
#    Impervious Cover (m2/person)  Tree Canopy Cover %  \
# 0                    303.464542             0.567194
# 1                    356.483994             0.575551
# 2                    462.955438             0.605966
# 3                    261.489004             0.715375
# 4                    276.601207             0.429399
#
#    Tree Canopy Cover (m2/person)  Total Green Space (ha)  \
# 0                    20026.33290             152866.9952
# 1                    16979.38254             409233.9968
# ...

# %%
forest_poverty_df = (pd.merge(forest_data_df,poverty_data_df, on=['FIPS']))
forest_poverty_df
# Out:
#     Unnamed: 0  Unnamed: 0.1 State_x    County_x  Mapping Zones  \
# 0         1744             3      NJ    Atlantic             60
# 1         1745             4      NJ      Bergen             64
# 2         1746             5      NJ  Burlington             60
# 3         1747             6      NJ      Camden             60
# 4         1748             8      NJ  Cumberland             60
# 5         1749             9      NJ       Essex             64
# 6         1750            10      NJ  Gloucester             60
# 7         1751            11      NJ      Hudson             64
# 8         1752            12      NJ   Hunterdon             60
# 9         1753            13      NJ      Mercer             60
# 10        1754            14      NJ   Middlesex             60
# 11        1755            15      NJ    Monmouth             60
# 12        1756            16      NJ      Morris             64
# 13        1757            17      NJ       Ocean             60
# ...

# %%
forest_poverty_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'State_x', 'County_x', 'Mapping Zones',
#        'Impervious Cover %', 'Impervious Cover (m2/person)',
#        'Tree Canopy Cover %', 'Tree Canopy Cover (m2/person)',
#        'Total Green Space (ha)',
#        ...
#        '95% CI - High.17', 'Z-Score.33', '% Drive Alone (Black)',
#        '% Drive Alone (Hispanic)', '% Drive Alone (White)',
#        '# Workers who Drive Alone', '% Long Commute - Drives Alone',
#        '95% CI - Low.18', '95% CI - High.18', 'Z-Score.34'],
#       dtype='object', length=174)

# %%
total_cols=len(forest_poverty_df.axes[1])
print(total_cols)
# Out:
# 174

# %%
total_rows=len(forest_poverty_df.axes[0])
print(total_rows)
# Out:
# 20

# %%
forest_poverty_df
# Out:
#     Unnamed: 0  Unnamed: 0.1 State_x    County_x  Mapping Zones  \
# 0         1744             3      NJ    Atlantic             60
# 1         1745             4      NJ      Bergen             64
# 2         1746             5      NJ  Burlington             60
# 3         1747             6      NJ      Camden             60
# 4         1748             8      NJ  Cumberland             60
# 5         1749             9      NJ       Essex             64
# 6         1750            10      NJ  Gloucester             60
# 7         1751            11      NJ      Hudson             64
# 8         1752            12      NJ   Hunterdon             60
# 9         1753            13      NJ      Mercer             60
# 10        1754            14      NJ   Middlesex             60
# 11        1755            15      NJ    Monmouth             60
# 12        1756            16      NJ      Morris             64
# 13        1757            17      NJ       Ocean             60
# ...

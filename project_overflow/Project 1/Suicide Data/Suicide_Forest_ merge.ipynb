# %%
#  Dependencies
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
suicide_data = "2016_suicide.csv"
suicide_data_df = pd.read_csv(suicide_data)
suicide_data_df.head()
# Out:
#             County State    FIPS Deaths Population  Crude Rate  \
# 0   Autauga County    AL  1001.0     14      55416  Unreliable
# 1   Baldwin County    AL  1003.0     42     208563        20.1
# 2    Blount County    AL  1009.0     11      57704  Unreliable
# 3   Calhoun County    AL  1015.0     25     114611        21.8
# 4  Chambers County    AL  1017.0     15      33843  Unreliable
#
#   Crude Rate Lower 95% Confidence Interval  \
# 0                                     13.8
# 1                                     14.5
# 2                                      9.5
# 3                                     14.1
# 4                                     24.8
#
#   Crude Rate Upper 95% Confidence Interval Crude Rate Standard Error  \
# 0                                     42.4                       6.8
# 1                                     27.2                       3.1
# 2                                     34.1                       5.7
# ...

# %%
forest_data = "forest_fips.csv"
forest_data_df = pd.read_csv(forest_data)
forest_data_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 State   County  Mapping Zones  Impervious Cover %  \
# 0           0             3    AL  Autauga             46            0.008595
# 1           1             4    AL  Baldwin             46            0.012084
# 2           2             5    AL  Barbour             46            0.005891
# 3           3             6    AL     Bibb             48            0.003383
# 4           4             7    AL   Blount             48            0.008458
#
#    Impervious Cover (m2/person)  Tree Canopy Cover %  \
# 0                    303.464542             0.567194
# 1                    356.483994             0.575551
# 2                    462.955438             0.605966
# 3                    261.489004             0.715375
# 4                    276.601207             0.429399
#
#    Tree Canopy Cover (m2/person)  Total Green Space (ha)  \
# 0                    20026.33290             152866.9952
# 1                    16979.38254             409233.9968
# ...

# %%
forest_suicide_df = (pd.merge(forest_data_df,suicide_data_df, on=['FIPS']))
forest_suicide_df
# Out:
#      Unnamed: 0  Unnamed: 0.1 State_x    County_x  Mapping Zones  \
# 0             0             3      AL     Autauga             46
# 1             1             4      AL     Baldwin             46
# 2             4             7      AL      Blount             48
# 3             7            10      AL     Calhoun             48
# 4             8            11      AL    Chambers             54
# 5            15            18      AL      Coffee             46
# 6            21            24      AL     Cullman             48
# 7            24            28      AL      Elmore             46
# 8            25            29      AL    Escambia             46
# 9            26            30      AL      Etowah             48
# 10           33            37      AL     Houston             46
# 11           34            38      AL     Jackson             48
# 12           35            39      AL   Jefferson             48
# ...

# %%
plt.scatter(forest_suicide_df["Tree Canopy Cover (m2/person)"],forest_suicide_df["Crude Rate"], 
           label = "Suicides vs Tree Canopy Cover (m2/person)")
plt.title("Suicides vs Tree Canopy Cover (m2/person)")
plt.xlabel("Canopy Cover (m2/person)")
plt.ylabel("Crude Rate of Suicides")
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.show()

# %%
fig.savefig('Suicide.')
